# %%
from profiler.core import *

# %% [markdown]
# ## 1. Instantiate Engine
# * workers : number of processes
# * tol     : tolerance for differences when creating training data (set to 0 if data is completely clean)
# * eps     : error bound for inverse covariance estimation (since we use conservative calculation when determining minimum sample size, we recommend to set eps <= 0.01)
# * embedtxt: if set to true, differentiate b/w textual data and categorical data, and use word embedding for the former

# %%
pf = Profiler(workers=2, tol=1e-6, eps=0.05, embedtxt=True)

# %% [markdown]
# ## 2. Load Data
# * name: any name you like
# * src: \[FILE; DF; DB (not implemented)\]
# * fpath: required if src == FILE
# * df: required if src == DF
# * check_param: print parameters used for data loading

# %%
pf.session.load_data(name='hospital', src=FILE, fpath='data/hospital.csv', check_param=True, na_values='empty')
# Out:
# INFO:profiler.utility:[0.007627010345458984] Load Data start
#
# INFO:profiler.data.dataset:parameters used for data loading:
#  {'na_values': 'empty', 'sep': ',', 'header': 'infer', 'dropcol': None, 'dropna': False, 'encoding': 'utf-8', 'normalize': True, 'min_categories_for_embedding': 10}
# WARNING:profiler.data.dataset:Dropping the following null column from the dataset: 'Address2'
# WARNING:profiler.data.dataset:Dropping the following null column from the dataset: 'Address3'
# INFO:profiler.data.dataset:inferred types of attributes: {
#     "ProviderNumber": "text",
#     "HospitalName": "text",
#     "Address1": "text",
#     "City": "text",
#     "State": "categorical",
#     "ZipCode": "text",
#     "CountyName": "text",
#     "PhoneNumber": "text",
#     "HospitalType": "text",
#     "HospitalOwner": "text",
#     "EmergencyService": "categorical",
#     "Condition": "text",
#     "MeasureCode": "text",
#     "MeasureName": "text",
#     "Score": "text",
#     "Sample": "text",
#     "Stateavg": "text"
# }
# INFO:profiler.data.dataset:(possible types: numeric, categorical, text, date)
# INFO:profiler.data.dataset:inferred operators of attributes: {'ProviderNumber': ['equal'], 'HospitalName': ['equal'], 'Address1': ['equal'], 'City': ['equal'], 'State': ['equal'], 'ZipCode': ['equal'], 'CountyName': ['equal'], 'PhoneNumber': ['equal'], 'HospitalType': ['equal'], 'HospitalOwner': ['equal'], 'EmergencyService': ['equal'], 'Condition': ['equal'], 'MeasureCode': ['equal'], 'MeasureName': ['equal'], 'Score': ['equal'], 'Sample': ['equal'], 'Stateavg': ['equal']}
# INFO:profiler.data.dataset:(possible operators: equal, notequal, greater_than, less_than)
# INFO:profiler.utility:[0.08453083038330078] Load Data execution time: 0.0769038200378418

# %% [markdown]
# ### 2.1 Change Data Types of Attributes
# * required input:
#     * a list of attributes
#     * a list of data types (must match the order of the attributes; can be CATEGORICAL, NUMERIC, TEXT, DATE)
# * optional input:
#     * a list of regular expression extractor

# %%
pf.session.change_dtypes(['ProviderNumber', 'ZipCode', 'PhoneNumber', 'State', 'EmergencyService','Score', 'Sample'], 
                            [CATEGORICAL, NUMERIC, CATEGORICAL, TEXT, TEXT, NUMERIC, NUMERIC],
                            [None, None, None, None, None, r'(\d+)%', r'(\d+)\spatients'])
# Out:
# INFO:profiler.data.dataset:updated types of ProviderNumber to 'categorical'
# INFO:profiler.data.dataset:updated operators of ProviderNumber to ['equal']
# INFO:profiler.data.dataset:updated types of ZipCode to 'numeric'
# INFO:profiler.data.dataset:updated operators of ZipCode to ['equal']
# INFO:profiler.data.dataset:updated types of PhoneNumber to 'categorical'
# INFO:profiler.data.dataset:updated operators of PhoneNumber to ['equal']
# INFO:profiler.data.dataset:updated types of State to 'text'
# INFO:profiler.data.dataset:updated operators of State to ['equal']
# INFO:profiler.data.dataset:updated types of EmergencyService to 'text'
# INFO:profiler.data.dataset:updated operators of EmergencyService to ['equal']
# INFO:profiler.data.dataset:updated types of Score to 'numeric'
# INFO:profiler.data.dataset:updated operators of Score to ['equal']
# INFO:profiler.data.dataset:updated types of Sample to 'numeric'
# INFO:profiler.data.dataset:updated operators of Sample to ['equal']
# INFO:profiler.data.dataset:updated inferred operators of attributes: {'ProviderNumber': ['equal'], 'HospitalName': ['equal'], 'Address1': ['equal'], 'City': ['equal'], 'State': ['equal'], 'ZipCode': ['equal'], 'CountyName': ['equal'], 'PhoneNumber': ['equal'], 'HospitalType': ['equal'], 'HospitalOwner': ['equal'], 'EmergencyService': ['equal'], 'Condition': ['equal'], 'MeasureCode': ['equal'], 'MeasureName': ['equal'], 'Score': ['equal'], 'Sample': ['equal'], 'Stateavg': ['equal']}

# %% [markdown]
# ### 2.2. Load/Train Embeddings for TEXT
# * path: path to saved/to-save embedding folder
# * load: set to true -- load saved vec from 'path'; set to false -- train locally
# * save: (only for load = False) save trained vectors to 'path'

# %%
pf.session.load_embedding(save=True, path='data/hospital-naive/', load=False, concate=False, mode="ft")
# Out:
# INFO:profiler.utility:[0.13373684883117676] Load Embedding start
#
# INFO:profiler.data.embedding:[HospitalName] tokenize cell
# INFO:profiler.data.embedding:[Address1] tokenize cell
# INFO:profiler.data.embedding:[HospitalName] train language model
# INFO:profiler.data.embedding:[Address1] train language model
# INFO:profiler.data.embedding:[HospitalName] compute weights
# INFO:profiler.data.embedding:[HospitalName] create vector map
# INFO:profiler.data.embedding:[HospitalName] save vec and vocab
# INFO:profiler.data.embedding:[City] tokenize cell
# INFO:profiler.data.embedding:[City] train language model
# INFO:profiler.data.embedding:[Address1] compute weights
# INFO:profiler.data.embedding:[Address1] create vector map
# INFO:profiler.data.embedding:[Address1] save vec and vocab
# INFO:profiler.data.embedding:[State] tokenize cell
# INFO:profiler.data.embedding:[State] train language model
# INFO:profiler.data.embedding:[City] compute weights
# INFO:profiler.data.embedding:[City] create vector map
# INFO:profiler.data.embedding:[City] save vec and vocab
# INFO:profiler.data.embedding:[CountyName] tokenize cell
# INFO:profiler.data.embedding:[CountyName] train language model
# INFO:profiler.data.embedding:[State] compute weights
# INFO:profiler.data.embedding:[State] create vector map
# INFO:profiler.data.embedding:[State] save vec and vocab
# INFO:profiler.data.embedding:[HospitalType] tokenize cell
# INFO:profiler.data.embedding:[HospitalType] train language model
# INFO:profiler.data.embedding:[CountyName] compute weights
# INFO:profiler.data.embedding:[CountyName] create vector map
# INFO:profiler.data.embedding:[CountyName] save vec and vocab
# INFO:profiler.data.embedding:[HospitalOwner] tokenize cell
# INFO:profiler.data.embedding:[HospitalOwner] train language model
# INFO:profiler.data.embedding:[HospitalType] compute weights
# INFO:profiler.data.embedding:[HospitalType] create vector map
# INFO:profiler.data.embedding:[HospitalType] save vec and vocab
# INFO:profiler.data.embedding:[EmergencyService] tokenize cell
# INFO:profiler.data.embedding:[EmergencyService] train language model
# INFO:profiler.data.embedding:[HospitalOwner] compute weights
# INFO:profiler.data.embedding:[HospitalOwner] create vector map
# INFO:profiler.data.embedding:[HospitalOwner] save vec and vocab
# INFO:profiler.data.embedding:[Condition] tokenize cell
# INFO:profiler.data.embedding:[Condition] train language model
# INFO:profiler.data.embedding:[EmergencyService] compute weights
# INFO:profiler.data.embedding:[EmergencyService] create vector map
# INFO:profiler.data.embedding:[EmergencyService] save vec and vocab
# INFO:profiler.data.embedding:[MeasureCode] tokenize cell
# INFO:profiler.data.embedding:[MeasureCode] train language model
# INFO:profiler.data.embedding:[Condition] compute weights
# INFO:profiler.data.embedding:[Condition] create vector map
# INFO:profiler.data.embedding:[Condition] save vec and vocab
# INFO:profiler.data.embedding:[MeasureName] tokenize cell
# INFO:profiler.data.embedding:[MeasureName] train language model
# INFO:profiler.data.embedding:[MeasureCode] compute weights
# INFO:profiler.data.embedding:[MeasureCode] create vector map
# INFO:profiler.data.embedding:[MeasureCode] save vec and vocab
# INFO:profiler.data.embedding:[Stateavg] tokenize cell
# INFO:profiler.data.embedding:[Stateavg] train language model
# INFO:profiler.data.embedding:[MeasureName] compute weights
# INFO:profiler.data.embedding:[MeasureName] create vector map
# INFO:profiler.data.embedding:[MeasureName] save vec and vocab
# INFO:profiler.data.embedding:[Stateavg] compute weights
# INFO:profiler.data.embedding:[Stateavg] create vector map
# INFO:profiler.data.embedding:[Stateavg] save vec and vocab
# INFO:profiler.utility:[143.00168991088867] Load Embedding execution time: 142.8679530620575

# %%
# load clean data
pf2 = Profiler(workers=2, tol=1e-6, eps=0.05, embedtxt=True)
pf2.session.load_data(name='hospital', src=FILE, fpath='data/hospital_clean_unflatten.csv', check_param=True, na_values='empty')
pf2.session.change_dtypes(['ProviderNumber', 'ZipCode', 'PhoneNumber', 'State', 'EmergencyService','Score', 'Sample'], 
                            [CATEGORICAL, NUMERIC, CATEGORICAL, TEXT, TEXT, NUMERIC, NUMERIC],
                            [None, None, None, None, None, r'(\d+)%', r'(\d+)\spatients'])
# Out:
# INFO:profiler.utility:[5.0067901611328125e-05] Load Data start
#
# INFO:profiler.data.dataset:parameters used for data loading:
#  {'na_values': 'empty', 'sep': ',', 'header': 'infer', 'dropcol': None, 'dropna': False, 'encoding': 'utf-8', 'normalize': True, 'min_categories_for_embedding': 10}
# WARNING:profiler.data.dataset:Dropping the following null column from the dataset: 'Address2'
# WARNING:profiler.data.dataset:Dropping the following null column from the dataset: 'Address3'
# INFO:profiler.data.dataset:inferred types of attributes: {
#     "ProviderNumber": "numeric",
#     "HospitalName": "text",
#     "Address1": "text",
#     "City": "text",
#     "State": "categorical",
#     "ZipCode": "numeric",
#     "CountyName": "text",
#     "PhoneNumber": "numeric",
#     "HospitalType": "categorical",
#     "HospitalOwner": "categorical",
#     "EmergencyService": "categorical",
#     "Condition": "categorical",
#     "MeasureCode": "text",
#     "MeasureName": "text",
#     "Score": "text",
#     "Sample": "text",
#     "Stateavg": "text"
# }
# INFO:profiler.data.dataset:(possible types: numeric, categorical, text, date)
# INFO:profiler.data.dataset:inferred operators of attributes: {'ProviderNumber': ['equal'], 'HospitalName': ['equal'], 'Address1': ['equal'], 'City': ['equal'], 'State': ['equal'], 'ZipCode': ['equal'], 'CountyName': ['equal'], 'PhoneNumber': ['equal'], 'HospitalType': ['equal'], 'HospitalOwner': ['equal'], 'EmergencyService': ['equal'], 'Condition': ['equal'], 'MeasureCode': ['equal'], 'MeasureName': ['equal'], 'Score': ['equal'], 'Sample': ['equal'], 'Stateavg': ['equal']}
# INFO:profiler.data.dataset:(possible operators: equal, notequal, greater_than, less_than)
# INFO:profiler.utility:[0.05260515213012695] Load Data execution time: 0.052555084228515625
#
# INFO:profiler.data.dataset:updated types of ProviderNumber to 'categorical'
# INFO:profiler.data.dataset:updated operators of ProviderNumber to ['equal']
# INFO:profiler.data.dataset:updated types of ZipCode to 'numeric'
# INFO:profiler.data.dataset:updated operators of ZipCode to ['equal']
# INFO:profiler.data.dataset:updated types of PhoneNumber to 'categorical'
# INFO:profiler.data.dataset:updated operators of PhoneNumber to ['equal']
# INFO:profiler.data.dataset:updated types of State to 'text'
# INFO:profiler.data.dataset:updated operators of State to ['equal']
# INFO:profiler.data.dataset:updated types of EmergencyService to 'text'
# INFO:profiler.data.dataset:updated operators of EmergencyService to ['equal']
# INFO:profiler.data.dataset:updated types of Score to 'numeric'
# INFO:profiler.data.dataset:updated operators of Score to ['equal']
# INFO:profiler.data.dataset:updated types of Sample to 'numeric'
# INFO:profiler.data.dataset:updated operators of Sample to ['equal']
# INFO:profiler.data.dataset:updated inferred operators of attributes: {'ProviderNumber': ['equal'], 'HospitalName': ['equal'], 'Address1': ['equal'], 'City': ['equal'], 'State': ['equal'], 'ZipCode': ['equal'], 'CountyName': ['equal'], 'PhoneNumber': ['equal'], 'HospitalType': ['equal'], 'HospitalOwner': ['equal'], 'EmergencyService': ['equal'], 'Condition': ['equal'], 'MeasureCode': ['equal'], 'MeasureName': ['equal'], 'Score': ['equal'], 'Sample': ['equal'], 'Stateavg': ['equal']}

# %%
clean = pf2.session.ds.df['HospitalName']
dirty = pf.session.ds.df['HospitalName']
vec = pf.session.embed.models['HospitalName'].vec
vocab = pf.session.embed.models['HospitalName'].vocab

# %%
vocab.loc[np.nan] = vocab.shape[0]-1

# %%
import pandas as pd

# %%
import sklearn
# 1. calculate cosine distances with all other values in the domain 
distance = sklearn.metrics.pairwise.cosine_distances(vec)

# %%
dis_with_same = []
dis_with_other = []
vocab['index'] = vocab['index'].astype(int)
for i, cell in enumerate(vocab.index):
    if not isinstance(cell, np.str):
        continue
    # for each word, find the corresponding correct word in clean data
    clean_cell = clean.loc[dirty.index[dirty==cell][0]]
    # find the index of the words in dirty vocab that equals to this word in groudtruth
    variations = dirty[(clean==clean_cell) & (dirty != cell)]
    variations = np.unique(variations[~pd.isnull(variations)])
    if len(variations) == 0:
        continue
    print("cell: %s"%cell)
    similar_idx = vocab.loc[variations,'index'].values
    same_idx = [vocab.loc[cell, 'index']]
    dis_with_same.extend(distance[i, similar_idx])
    print("\n-- distance with variational representations of the word -- ")
    maxdis = -1
    for word, dis in zip(variations, distance[i, vocab.loc[variations, 'index']]):
        print("%s (%.4f)"%(word, dis))
        maxdis = max(dis, maxdis)
    
    nonsimilar_idx = np.array(list(set(vocab['index'].values) - set(similar_idx) - set(same_idx)))

    nonsimilar_dis = distance[i, nonsimilar_idx]
    dis_with_other.extend(nonsimilar_dis)
    print("\n-- nonsimilar words but with small distances --")
    for word, dis in zip(vocab.index.values[nonsimilar_idx[nonsimilar_dis<maxdis]], nonsimilar_dis[nonsimilar_dis<maxdis]):
        print("%s (%.4f)"%(word, dis))
    print("\n====")
# Out:
# cell: alaska regional hospital
#
# -- distance with variational representations of the word --
# xlxskx regionxl hospitxl (0.0964)
#
# -- nonsimilar words but with small distances --
# andalusia regional hospital (0.0011)
# andaluxia regional hoxpital (0.0303)
# andaxusia regionax hospitax (0.0679)
# prattville baptist hospital (0.0724)
#
# ====
# cell: andalusia regional hospital
#
# -- distance with variational representations of the word --
# andaluxia regional hoxpital (0.0255)
# andaxusia regionax hospitax (0.0626)
#
# -- nonsimilar words but with small distances --
# alaska regional hospital (0.0011)
#
# ====
# cell: andaluxia regional hoxpital
#
# -- distance with variational representations of the word --
# andalusia regional hospital (0.0255)
# andaxusia regionax hospitax (0.0388)
#
# -- nonsimilar words but with small distances --
# alaska regional hospital (0.0303)
#
# ====
# cell: andaxusia regionax hospitax
#
# -- distance with variational representations of the word --
# andalusia regional hospital (0.0626)
# andaluxia regional hoxpital (0.0388)
#
# -- nonsimilar words but with small distances --
# huntsvxlle hospxtal (0.0520)
# prattville baptist hospital (0.0553)
# rivxrvixw rxgional mxdical cxntxr (0.0217)
# xlxskx regionxl hospitxl (0.0033)
# yukon kuskokwim delta reg hospital (0.0406)
#
# ====
# cell: baptist medical center south
#
# -- distance with variational representations of the word --
# baptist medical cexter south (0.0055)
#
# -- nonsimilar words but with small distances --
# marshall medical center south (0.0014)
#
# ====
# cell: baptist medical cexter south
#
# -- distance with variational representations of the word --
# baptist medical center south (0.0055)
#
# -- nonsimilar words but with small distances --
#
# ====
# cell: communitx hospital inc
#
# -- distance with variational representations of the word --
# community hospital inc (0.0006)
# communixy hospixal inc (0.0128)
#
# -- nonsimilar words but with small distances --
# crenshaw community hospital (0.0082)
# crenshaw cxmmunity hxspital (0.0101)
#
# ====
# cell: community hospital inc
#
# -- distance with variational representations of the word --
# communitx hospital inc (0.0006)
# communixy hospixal inc (0.0130)
#
# -- nonsimilar words but with small distances --
# crenshaw community hospital (0.0083)
# crenshaw cxmmunity hxspital (0.0106)
#
# ====
# cell: communixy hospixal inc
#
# -- distance with variational representations of the word --
# communitx hospital inc (0.0128)
# community hospital inc (0.0130)
#
# -- nonsimilar words but with small distances --
# jackson hospital & clinic inc (0.0125)
# jaxkson hospital & xlinix inx (0.0031)
#
# ====
# cell: crenshaw community hospital
#
# -- distance with variational representations of the word --
# crenshaw cxmmunity hxspital (0.0116)
#
# -- nonsimilar words but with small distances --
# communitx hospital inc (0.0082)
# community hospital inc (0.0083)
#
# ====
# cell: crenshaw cxmmunity hxspital
#
# -- distance with variational representations of the word --
# crenshaw community hospital (0.0116)
#
# -- nonsimilar words but with small distances --
# communitx hospital inc (0.0101)
# community hospital inc (0.0106)
#
# ====
# cell: cullman regional medical center
#
# -- distance with variational representations of the word --
# cullmxn regionxl medicxl center (0.0508)
#
# -- nonsimilar words but with small distances --
# baptist medical center south (0.0474)
# cherokee medical center (0.0178)
# chilton medical center (0.0172)
# coosa valley medical center (0.0406)
# dale medical center (0.0167)
# dekalb regional medical center (0.0001)
# dexalb regional medical center (0.0013)
# fayette medical center (0.0164)
# gadsden regional medical center (0.0002)
# hartselle medical center (0.0153)
# marion regional medical center (0.0005)
# marshall medical center north (0.0232)
# marshall medical center south (0.0456)
# marshall medical cenxer norxh (0.0405)
# medical center enterprise (0.0166)
# medxcal center enterprxse (0.0363)
# northwest medical center (0.0267)
# riverview regional medical center (0.0004)
# riverview rexional medical center (0.0044)
# shelby baptist medical center (0.0180)
# xivexview xegional medical centex (0.0335)
#
# ====
# cell: cullmxn regionxl medicxl center
#
# -- distance with variational representations of the word --
# cullman regional medical center (0.0508)
#
# -- nonsimilar words but with small distances --
# coosa valley medical center (0.0399)
# dekalb regional medical center (0.0501)
# gadsden regional medical center (0.0492)
# marshall medical cenxer norxh (0.0140)
# medixal xenter enterprise (0.0047)
# medxcal center enterprxse (0.0108)
# riverview regional medical center (0.0476)
# riverview rexional medical center (0.0409)
# shelby baptist medical center (0.0465)
# xivexview xegional medical centex (0.0036)
#
# ====
# cell: dekalb regional medical center
#
# -- distance with variational representations of the word --
# dexalb regional medical center (0.0012)
#
# -- nonsimilar words but with small distances --
# cullman regional medical center (0.0001)
# gadsden regional medical center (0.0001)
# marion regional medical center (0.0006)
# riverview regional medical center (0.0002)
#
# ====
# cell: dexalb regional medical center
#
# -- distance with variational representations of the word --
# dekalb regional medical center (0.0012)
#
# -- nonsimilar words but with small distances --
# gadsden regional medical center (0.0008)
#
# ====
# cell: flowers hospital
#
# -- distance with variational representations of the word --
# floxers hospital (0.0145)
#
# -- nonsimilar words but with small distances --
# georgiana hospital (0.0019)
# georgiaxa hospital (0.0025)
# huntsville hospital (0.0044)
# wedowee hospital (0.0016)
#
# ====
# cell: floxers hospital
#
# -- distance with variational representations of the word --
# flowers hospital (0.0145)
#
# -- nonsimilar words but with small distances --
# georgiaxa hospital (0.0087)
# russellville hospital (0.0037)
#
# ====
# cell: georgiana hospital
#
# -- distance with variational representations of the word --
# georgiaxa hospital (0.0037)
#
# -- nonsimilar words but with small distances --
# flowers hospital (0.0019)
# wedowee hospital (0.0018)
#
# ====
# cell: georgiaxa hospital
#
# -- distance with variational representations of the word --
# georgiana hospital (0.0037)
#
# -- nonsimilar words but with small distances --
# flowers hospital (0.0025)
#
# ====
# cell: huntsville hospital
#
# -- distance with variational representations of the word --
# huntsvxlle hospxtal (0.0974)
#
# -- nonsimilar words but with small distances --
# crenshaw community hospital (0.0679)
# crenshaw cxmmunity hxspital (0.0766)
# decatur general hospital (0.0399)
# elba general hospital (0.0511)
# eliza coffee memorial hospital (0.0795)
# flowers hospital (0.0044)
# floxers hospital (0.0224)
# georgiana hospital (0.0059)
# georgiaxa hospital (0.0086)
# helen keller memorial hospital (0.0855)
# mizell memorial hospital (0.0731)
# russellville hospital (0.0192)
# stringfellow memorial hospital (0.0670)
# wedowee hospital (0.0021)
# wedowee hosxital (0.0275)
#
# ====
# cell: huntsvxlle hospxtal
#
# -- distance with variational representations of the word --
# huntsville hospital (0.0974)
#
# -- nonsimilar words but with small distances --
# andaxusia regionax hospitax (0.0520)
# crenshaw cxmmunity hxspital (0.0805)
# jaxkson hospital & xlinix inx (0.0938)
# rivxrvixw rxgional mxdical cxntxr (0.0718)
# wedowee hosxital (0.0466)
# xlxskx regionxl hospitxl (0.0351)
# yukon kuskokwim delta reg hospital (0.0023)
#
# ====
# cell: jackson hospital & clinic inc
#
# -- distance with variational representations of the word --
# jaxkson hospital & xlinix inx (0.0142)
#
# -- nonsimilar words but with small distances --
# communixy hospixal inc (0.0125)
#
# ====
# cell: jaxkson hospital & xlinix inx
#
# -- distance with variational representations of the word --
# jackson hospital & clinic inc (0.0142)
#
# -- nonsimilar words but with small distances --
# communixy hospixal inc (0.0031)
#
# ====
# cell: marshall medical center north
#
# -- distance with variational representations of the word --
# marshall medical cenxer norxh (0.0232)
#
# -- nonsimilar words but with small distances --
# baptist medical center south (0.0083)
# cherokee medical center (0.0060)
# chilton medical center (0.0042)
# cullman regional medical center (0.0232)
# dale medical center (0.0043)
# dekalb regional medical center (0.0211)
# fayette medical center (0.0052)
# gadsden regional medical center (0.0229)
# hartselle medical center (0.0057)
# marion regional medical center (0.0223)
# marshall medical center south (0.0062)
# medical center enterprise (0.0061)
# northwest medical center (0.0039)
# riverview regional medical center (0.0192)
# riverview rexional medical center (0.0107)
# shelby baptist medical center (0.0045)
#
# ====
# cell: marshall medical cenxer norxh
#
# -- distance with variational representations of the word --
# marshall medical center north (0.0232)
#
# -- nonsimilar words but with small distances --
# baptist medical center south (0.0222)
# baptist medical cexter south (0.0224)
# cullmxn regionxl medicxl center (0.0140)
# medixal xenter enterprise (0.0057)
# medxcal center enterprxse (0.0056)
# shelby baptist medical center (0.0182)
# xivexview xegional medical centex (0.0132)
#
# ====
# cell: medical center enterprise
#
# -- distance with variational representations of the word --
# medixal xenter enterprise (0.0486)
# medxcal center enterprxse (0.0251)
#
# -- nonsimilar words but with small distances --
# baptist medical center south (0.0187)
# baptist medical cexter south (0.0412)
# cherokee medical center (0.0001)
# chilton medical center (0.0005)
# coosa valley medical center (0.0349)
# cullman regional medical center (0.0166)
# dale medical center (0.0003)
# dekalb regional medical center (0.0146)
# dexalb regional medical center (0.0166)
# fayette medical center (0.0001)
# gadsden regional medical center (0.0154)
# hartselle medical center (0.0003)
# marion regional medical center (0.0178)
# marshall medical center north (0.0061)
# marshall medical center south (0.0183)
# marshall medical cenxer norxh (0.0310)
# northwest medical center (0.0022)
# riverview regional medical center (0.0133)
# riverview rexional medical center (0.0057)
# shelby baptist medical center (0.0053)
# southeast alabama medical center (0.0442)
# southwest alabama medical center (0.0404)
# xivexview xegional medical centex (0.0460)
#
# ====
# cell: medixal xenter enterprise
#
# -- distance with variational representations of the word --
# medical center enterprise (0.0486)
# medxcal center enterprxse (0.0055)
#
# -- nonsimilar words but with small distances --
# baptist medical center south (0.0405)
# baptist medical cexter south (0.0383)
# cherokee medical center (0.0481)
# chilton medical center (0.0468)
# coosa valley medical center (0.0313)
# cullmxn regionxl medicxl center (0.0047)
# dale medical center (0.0484)
# fayette medical center (0.0474)
# hartselle medical center (0.0465)
# marshall medical center north (0.0422)
# marshall medical center south (0.0447)
# marshall medical cenxer norxh (0.0057)
# northwest medical center (0.0472)
# riverview rexional medical center (0.0377)
# shelby baptist medical center (0.0353)
# xivexview xegional medical centex (0.0096)
#
# ====
# cell: medxcal center enterprxse
#
# -- distance with variational representations of the word --
# medical center enterprise (0.0251)
# medixal xenter enterprise (0.0055)
#
# -- nonsimilar words but with small distances --
# cherokee medical center (0.0248)
# chilton medical center (0.0248)
# cullmxn regionxl medicxl center (0.0108)
# fayette medical center (0.0247)
# hartselle medical center (0.0241)
# marshall medical cenxer norxh (0.0056)
# riverview rexional medical center (0.0203)
# shelby baptist medical center (0.0191)
# xivexview xegional medical centex (0.0110)
#
# ====
# cell: riverview regional medical center
#
# -- distance with variational representations of the word --
# riverview rexional medical center (0.0026)
# rivxrvixw rxgional mxdical cxntxr (0.2075)
# xivexview xegional medical centex (0.0310)
#
# -- nonsimilar words but with small distances --
# andaluxia regional hoxpital (0.1426)
# baptist medical center south (0.0404)
# baptist medical cexter south (0.0624)
# cherokee medical center (0.0143)
# chilton medical center (0.0138)
# coosa valley medical center (0.0378)
# cullman regional medical center (0.0004)
# cullmxn regionxl medicxl center (0.0476)
# dale medical center (0.0133)
# dekalb regional medical center (0.0002)
# dexalb regional medical center (0.0014)
# fayette medical center (0.0130)
# gadsden regional medical center (0.0003)
# hartselle medical center (0.0121)
# marion regional medical center (0.0010)
# marshall medical center north (0.0192)
# marshall medical center south (0.0392)
# marshall medical cenxer norxh (0.0356)
# medical center enterprise (0.0133)
# medixal xenter enterprise (0.0489)
# medxcal center enterprxse (0.0316)
# northwest medical center (0.0221)
# shelby baptist medical center (0.0141)
# southeast alabama medical center (0.0891)
# southeast alabama medxcal center (0.1275)
# southwest alabama medical center (0.0826)
# univ of south alabama medical center (0.1845)
# univ ox south alabama medical center (0.1391)
# xniv of soxth alabama medical center (0.1470)
#
# ====
# cell: riverview rexional medical center
#
# -- distance with variational representations of the word --
# riverview regional medical center (0.0026)
# rivxrvixw rxgional mxdical cxntxr (0.1995)
# xivexview xegional medical centex (0.0273)
#
# -- nonsimilar words but with small distances --
# andaluxia regional hoxpital (0.1551)
# baptist medical center south (0.0267)
# baptist medical cexter south (0.0464)
# cherokee medical center (0.0063)
# chilton medical center (0.0059)
# coosa valley medical center (0.0299)
# cullman regional medical center (0.0044)
# cullmxn regionxl medicxl center (0.0409)
# dale medical center (0.0058)
# dekalb regional medical center (0.0035)
# dexalb regional medical center (0.0055)
# east alabama medical center and snf (0.1746)
# fayette medical center (0.0055)
# gadsden regional medical center (0.0039)
# hartselle medical center (0.0050)
# marion regional medical center (0.0051)
# marshall medical center north (0.0107)
# marshall medical center south (0.0262)
# marshall medical cenxer norxh (0.0242)
# medical center enterprise (0.0057)
# medixal xenter enterprise (0.0377)
# medxcal center enterprxse (0.0203)
# northwest medical center (0.0115)
# shelby baptist medical center (0.0069)
# southeast alabama medical center (0.0644)
# southeast alabama medxcal center (0.0982)
# southwest alabama medical center (0.0590)
# univ of south alabama medical center (0.1519)
# univ ox south alabama medical center (0.1104)
# xniv of soxth alabama medical center (0.1166)
#
# ====
# cell: rivxrvixw rxgional mxdical cxntxr
#
# -- distance with variational representations of the word --
# riverview regional medical center (0.2075)
# riverview rexional medical center (0.1995)
# xivexview xegional medical centex (0.0844)
#
# -- nonsimilar words but with small distances --
# alaska regional hospital (0.1274)
# andalusia regional hospital (0.1214)
# andaluxia regional hoxpital (0.0551)
# andaxusia regionax hospitax (0.0217)
# baptist medical cexter south (0.1870)
# coosa valley medical center (0.1652)
# cullmxn regionxl medicxl center (0.0659)
# huntsvxlle hospxtal (0.0718)
# marshall medical cenxer norxh (0.1133)
# medixal xenter enterprise (0.0812)
# medxcal center enterprxse (0.1187)
# prattville baptist hospital (0.0937)
# shelby baptist medical center (0.2051)
# southeast alabama medxcal center (0.2004)
# wedowee hosxital (0.2039)
# xlxskx regionxl hospitxl (0.0157)
# xniv of soxth alabama medical center (0.1880)
# yukon kuskokwim delta reg hospital (0.0658)
#
# ====
# cell: southeast alabama medical center
#
# -- distance with variational representations of the word --
# southeast alabama medxcal center (0.0088)
#
# -- nonsimilar words but with small distances --
# southwest alabama medical center (0.0004)
#
# ====
# cell: southeast alabama medxcal center
#
# -- distance with variational representations of the word --
# southeast alabama medical center (0.0088)
#
# -- nonsimilar words but with small distances --
#
# ====
# cell: st vincents blount
#
# -- distance with variational representations of the word --
# st vincents bxount (0.0004)
#
# -- nonsimilar words but with small distances --
#
# ====
# cell: st vincents bxount
#
# -- distance with variational representations of the word --
# st vincents blount (0.0004)
#
# -- nonsimilar words but with small distances --
#
# ====
# cell: univ of south alabama medical center
#
# -- distance with variational representations of the word --
# univ ox south alabama medical center (0.0055)
# xniv of soxth alabama medical center (0.0109)
#
# -- nonsimilar words but with small distances --
#
# ====
# cell: univ ox south alabama medical center
#
# -- distance with variational representations of the word --
# univ of south alabama medical center (0.0055)
# xniv of soxth alabama medical center (0.0109)
#
# -- nonsimilar words but with small distances --
#
# ====
# cell: wedowee hospital
#
# -- distance with variational representations of the word --
# wedowee hosxital (0.0293)
#
# -- nonsimilar words but with small distances --
# flowers hospital (0.0016)
# floxers hospital (0.0221)
# georgiana hospital (0.0018)
# georgiaxa hospital (0.0056)
# huntsville hospital (0.0021)
# russellville hospital (0.0231)
#
# ====
# cell: wedowee hosxital
#
# -- distance with variational representations of the word --
# wedowee hospital (0.0293)
#
# -- nonsimilar words but with small distances --
# huntsville hospital (0.0275)
#
# ====
# cell: xivexview xegional medical centex
#
# -- distance with variational representations of the word --
# riverview regional medical center (0.0310)
# riverview rexional medical center (0.0273)
# rivxrvixw rxgional mxdical cxntxr (0.0844)
#
# -- nonsimilar words but with small distances --
# andaluxia regional hoxpital (0.0739)
# baptist medical center south (0.0564)
# baptist medical cexter south (0.0603)
# cherokee medical center (0.0462)
# chilton medical center (0.0458)
# coosa valley medical center (0.0370)
# cullman regional medical center (0.0335)
# cullmxn regionxl medicxl center (0.0036)
# dale medical center (0.0470)
# dekalb regional medical center (0.0330)
# dexalb regional medical center (0.0333)
# fayette medical center (0.0453)
# gadsden regional medical center (0.0321)
# hartselle medical center (0.0437)
# marion regional medical center (0.0347)
# marshall medical center north (0.0481)
# marshall medical center south (0.0608)
# marshall medical cenxer norxh (0.0132)
# medical center enterprise (0.0460)
# medixal xenter enterprise (0.0096)
# medxcal center enterprxse (0.0110)
# northwest medical center (0.0522)
# shelby baptist medical center (0.0352)
#
# ====
# cell: xlxskx regionxl hospitxl
#
# -- distance with variational representations of the word --
# alaska regional hospital (0.0964)
#
# -- nonsimilar words but with small distances --
# andalusia regional hospital (0.0911)
# andaluxia regional hoxpital (0.0579)
# andaxusia regionax hospitax (0.0033)
# huntsvxlle hospxtal (0.0351)
# prattville baptist hospital (0.0602)
# rivxrvixw rxgional mxdical cxntxr (0.0157)
# yukon kuskokwim delta reg hospital (0.0276)
#
# ====
# cell: xniv of soxth alabama medical center
#
# -- distance with variational representations of the word --
# univ of south alabama medical center (0.0109)
# univ ox south alabama medical center (0.0109)
#
# -- nonsimilar words but with small distances --
#
# ====

# %%
data1 = pd.DataFrame(data=dis_with_same)
ax1 = data1.hist(bins=np.arange(0,1,0.1))[0][0]
ax1.set_title('[Average-Fasttext Embedding] \nHistogram of cosine distance\n between similar words')
ax1.set_xlabel('cosine distance')
ax1.set_ylabel('count')
data2 = pd.DataFrame(data=dis_with_other)
ax2 = data2.hist(bins=np.arange(0,1,0.1))[0][0]
ax2.set_title('[Average-Fasttext Embedding] \nHistogram of cosine distance\n between non-similar words')
ax2.set_xlabel('cosine distance')
ax2.set_ylabel('count')
# Out:
# Text(0, 0.5, 'count')
