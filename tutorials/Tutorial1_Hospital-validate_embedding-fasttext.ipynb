# %%
from profiler.core import *

# %% [markdown]
# ## 1. Instantiate Engine
# * workers : number of processes
# * tol     : tolerance for differences when creating training data (set to 0 if data is completely clean)
# * eps     : error bound for inverse covariance estimation (since we use conservative calculation when determining minimum sample size, we recommend to set eps <= 0.01)
# * embedtxt: if set to true, differentiate b/w textual data and categorical data, and use word embedding for the former

# %%
pf = Profiler(workers=2, tol=1e-6, eps=0.05, embedtxt=True)

# %% [markdown]
# ## 2. Load Data
# * name: any name you like
# * src: \[FILE; DF; DB (not implemented)\]
# * fpath: required if src == FILE
# * df: required if src == DF
# * check_param: print parameters used for data loading

# %%
pf.session.load_data(name='hospital', src=FILE, fpath='data/hospital.csv', check_param=True, na_values='empty')
# Out:
# INFO:profiler.utility:[0.0066432952880859375] Load Data start
#
# INFO:profiler.utility:[0.0066432952880859375] Load Data start
#
# INFO:profiler.data.dataset:parameters used for data loading:
#  {'na_values': 'empty', 'sep': ',', 'header': 'infer', 'dropcol': None, 'dropna': False, 'encoding': 'utf-8', 'normalize': True, 'min_categories_for_embedding': 10}
# INFO:profiler.data.dataset:parameters used for data loading:
#  {'na_values': 'empty', 'sep': ',', 'header': 'infer', 'dropcol': None, 'dropna': False, 'encoding': 'utf-8', 'normalize': True, 'min_categories_for_embedding': 10}
# WARNING:profiler.data.dataset:Dropping the following null column from the dataset: 'Address2'
# WARNING:profiler.data.dataset:Dropping the following null column from the dataset: 'Address2'
# WARNING:profiler.data.dataset:Dropping the following null column from the dataset: 'Address3'
# WARNING:profiler.data.dataset:Dropping the following null column from the dataset: 'Address3'
# INFO:profiler.data.dataset:inferred types of attributes: {
#     "ProviderNumber": "text",
#     "HospitalName": "text",
#     "Address1": "text",
#     "City": "text",
#     "State": "categorical",
#     "ZipCode": "text",
#     "CountyName": "text",
#     "PhoneNumber": "text",
#     "HospitalType": "text",
#     "HospitalOwner": "text",
#     "EmergencyService": "categorical",
#     "Condition": "text",
#     "MeasureCode": "text",
#     "MeasureName": "text",
#     "Score": "text",
#     "Sample": "text",
#     "Stateavg": "text"
# }
# INFO:profiler.data.dataset:(possible types: numeric, categorical, text, date)
# INFO:profiler.data.dataset:inferred types of attributes: {
#     "ProviderNumber": "text",
#     "HospitalName": "text",
#     "Address1": "text",
#     "City": "text",
#     "State": "categorical",
#     "ZipCode": "text",
#     "CountyName": "text",
#     "PhoneNumber": "text",
#     "HospitalType": "text",
#     "HospitalOwner": "text",
#     "EmergencyService": "categorical",
#     "Condition": "text",
#     "MeasureCode": "text",
#     "MeasureName": "text",
#     "Score": "text",
#     "Sample": "text",
#     "Stateavg": "text"
# }
# INFO:profiler.data.dataset:inferred operators of attributes: {'ProviderNumber': ['equal'], 'HospitalName': ['equal'], 'Address1': ['equal'], 'City': ['equal'], 'State': ['equal'], 'ZipCode': ['equal'], 'CountyName': ['equal'], 'PhoneNumber': ['equal'], 'HospitalType': ['equal'], 'HospitalOwner': ['equal'], 'EmergencyService': ['equal'], 'Condition': ['equal'], 'MeasureCode': ['equal'], 'MeasureName': ['equal'], 'Score': ['equal'], 'Sample': ['equal'], 'Stateavg': ['equal']}
# INFO:profiler.data.dataset:(possible types: numeric, categorical, text, date)
# INFO:profiler.data.dataset:(possible operators: equal, notequal, greater_than, less_than)
# INFO:profiler.data.dataset:inferred operators of attributes: {'ProviderNumber': ['equal'], 'HospitalName': ['equal'], 'Address1': ['equal'], 'City': ['equal'], 'State': ['equal'], 'ZipCode': ['equal'], 'CountyName': ['equal'], 'PhoneNumber': ['equal'], 'HospitalType': ['equal'], 'HospitalOwner': ['equal'], 'EmergencyService': ['equal'], 'Condition': ['equal'], 'MeasureCode': ['equal'], 'MeasureName': ['equal'], 'Score': ['equal'], 'Sample': ['equal'], 'Stateavg': ['equal']}
# INFO:profiler.utility:[0.07455611228942871] Load Data execution time: 0.06791281700134277
#
# INFO:profiler.data.dataset:(possible operators: equal, notequal, greater_than, less_than)
# INFO:profiler.utility:[0.07455611228942871] Load Data execution time: 0.06791281700134277

# %% [markdown]
# ### 2.1 Change Data Types of Attributes
# * required input:
#     * a list of attributes
#     * a list of data types (must match the order of the attributes; can be CATEGORICAL, NUMERIC, TEXT, DATE)
# * optional input:
#     * a list of regular expression extractor

# %%
pf.session.change_dtypes(['ProviderNumber', 'ZipCode', 'PhoneNumber', 'State', 'EmergencyService','Score', 'Sample'], 
                            [CATEGORICAL, NUMERIC, CATEGORICAL, TEXT, TEXT, NUMERIC, NUMERIC],
                            [None, None, None, None, None, r'(\d+)%', r'(\d+)\spatients'])
# Out:
# INFO:profiler.data.dataset:updated types of ProviderNumber to 'categorical'
# INFO:profiler.data.dataset:updated operators of ProviderNumber to ['equal']
# INFO:profiler.data.dataset:updated types of ProviderNumber to 'categorical'
# INFO:profiler.data.dataset:updated types of ZipCode to 'numeric'
# INFO:profiler.data.dataset:updated operators of ProviderNumber to ['equal']
# INFO:profiler.data.dataset:updated operators of ZipCode to ['equal']
# INFO:profiler.data.dataset:updated types of ZipCode to 'numeric'
# INFO:profiler.data.dataset:updated types of PhoneNumber to 'categorical'
# INFO:profiler.data.dataset:updated operators of ZipCode to ['equal']
# INFO:profiler.data.dataset:updated operators of PhoneNumber to ['equal']
# INFO:profiler.data.dataset:updated types of PhoneNumber to 'categorical'
# INFO:profiler.data.dataset:updated types of State to 'text'
# INFO:profiler.data.dataset:updated operators of PhoneNumber to ['equal']
# INFO:profiler.data.dataset:updated operators of State to ['equal']
# INFO:profiler.data.dataset:updated types of State to 'text'
# INFO:profiler.data.dataset:updated types of EmergencyService to 'text'
# INFO:profiler.data.dataset:updated operators of State to ['equal']
# INFO:profiler.data.dataset:updated operators of EmergencyService to ['equal']
# INFO:profiler.data.dataset:updated types of EmergencyService to 'text'
# INFO:profiler.data.dataset:updated types of Score to 'numeric'
# INFO:profiler.data.dataset:updated operators of EmergencyService to ['equal']
# INFO:profiler.data.dataset:updated operators of Score to ['equal']
# INFO:profiler.data.dataset:updated types of Score to 'numeric'
# INFO:profiler.data.dataset:updated types of Sample to 'numeric'
# INFO:profiler.data.dataset:updated operators of Score to ['equal']
# INFO:profiler.data.dataset:updated operators of Sample to ['equal']
# INFO:profiler.data.dataset:updated types of Sample to 'numeric'
# INFO:profiler.data.dataset:updated inferred operators of attributes: {'ProviderNumber': ['equal'], 'HospitalName': ['equal'], 'Address1': ['equal'], 'City': ['equal'], 'State': ['equal'], 'ZipCode': ['equal'], 'CountyName': ['equal'], 'PhoneNumber': ['equal'], 'HospitalType': ['equal'], 'HospitalOwner': ['equal'], 'EmergencyService': ['equal'], 'Condition': ['equal'], 'MeasureCode': ['equal'], 'MeasureName': ['equal'], 'Score': ['equal'], 'Sample': ['equal'], 'Stateavg': ['equal']}
# INFO:profiler.data.dataset:updated operators of Sample to ['equal']
# INFO:profiler.data.dataset:updated inferred operators of attributes: {'ProviderNumber': ['equal'], 'HospitalName': ['equal'], 'Address1': ['equal'], 'City': ['equal'], 'State': ['equal'], 'ZipCode': ['equal'], 'CountyName': ['equal'], 'PhoneNumber': ['equal'], 'HospitalType': ['equal'], 'HospitalOwner': ['equal'], 'EmergencyService': ['equal'], 'Condition': ['equal'], 'MeasureCode': ['equal'], 'MeasureName': ['equal'], 'Score': ['equal'], 'Sample': ['equal'], 'Stateavg': ['equal']}

# %% [markdown]
# ### 2.2. Load/Train Embeddings for TEXT
# * path: path to saved/to-save embedding folder
# * load: set to true -- load saved vec from 'path'; set to false -- train locally
# * save: (only for load = False) save trained vectors to 'path'

# %%
pf.session.load_embedding(save=True, path='data/hospital-naive/', load=True, mode="ft")
# Out:
# INFO:profiler.utility:[0.1181480884552002] Load Embedding start
#
# INFO:profiler.utility:[0.1181480884552002] Load Embedding start
#
# INFO:profiler.utility:[0.1576690673828125] Load Embedding execution time: 0.039520978927612305
#
# INFO:profiler.utility:[0.1576690673828125] Load Embedding execution time: 0.039520978927612305

# %%
# load clean data
pf2 = Profiler(workers=2, tol=1e-6, eps=0.05, embedtxt=True)
pf2.session.load_data(name='hospital', src=FILE, fpath='data/hospital_clean_unflatten.csv', check_param=True, na_values='empty')
pf2.session.change_dtypes(['ProviderNumber', 'ZipCode', 'PhoneNumber', 'State', 'EmergencyService','Score', 'Sample'], 
                            [CATEGORICAL, NUMERIC, CATEGORICAL, TEXT, TEXT, NUMERIC, NUMERIC],
                            [None, None, None, None, None, r'(\d+)%', r'(\d+)\spatients'])
# Out:
# INFO:profiler.utility:[7.009506225585938e-05] Load Data start
#
# INFO:profiler.utility:[7.009506225585938e-05] Load Data start
#
# INFO:profiler.data.dataset:parameters used for data loading:
#  {'na_values': 'empty', 'sep': ',', 'header': 'infer', 'dropcol': None, 'dropna': False, 'encoding': 'utf-8', 'normalize': True, 'min_categories_for_embedding': 10}
# INFO:profiler.data.dataset:parameters used for data loading:
#  {'na_values': 'empty', 'sep': ',', 'header': 'infer', 'dropcol': None, 'dropna': False, 'encoding': 'utf-8', 'normalize': True, 'min_categories_for_embedding': 10}
# WARNING:profiler.data.dataset:Dropping the following null column from the dataset: 'Address2'
# WARNING:profiler.data.dataset:Dropping the following null column from the dataset: 'Address2'
# WARNING:profiler.data.dataset:Dropping the following null column from the dataset: 'Address3'
# WARNING:profiler.data.dataset:Dropping the following null column from the dataset: 'Address3'
# INFO:profiler.data.dataset:inferred types of attributes: {
#     "ProviderNumber": "numeric",
#     "HospitalName": "text",
#     "Address1": "text",
#     "City": "text",
#     "State": "categorical",
#     "ZipCode": "numeric",
#     "CountyName": "text",
#     "PhoneNumber": "numeric",
#     "HospitalType": "categorical",
#     "HospitalOwner": "categorical",
#     "EmergencyService": "categorical",
#     "Condition": "categorical",
#     "MeasureCode": "text",
#     "MeasureName": "text",
#     "Score": "text",
#     "Sample": "text",
#     "Stateavg": "text"
# }
# INFO:profiler.data.dataset:(possible types: numeric, categorical, text, date)
# INFO:profiler.data.dataset:inferred types of attributes: {
#     "ProviderNumber": "numeric",
#     "HospitalName": "text",
#     "Address1": "text",
#     "City": "text",
#     "State": "categorical",
#     "ZipCode": "numeric",
#     "CountyName": "text",
#     "PhoneNumber": "numeric",
#     "HospitalType": "categorical",
#     "HospitalOwner": "categorical",
#     "EmergencyService": "categorical",
#     "Condition": "categorical",
#     "MeasureCode": "text",
#     "MeasureName": "text",
#     "Score": "text",
#     "Sample": "text",
#     "Stateavg": "text"
# }
# INFO:profiler.data.dataset:inferred operators of attributes: {'ProviderNumber': ['equal'], 'HospitalName': ['equal'], 'Address1': ['equal'], 'City': ['equal'], 'State': ['equal'], 'ZipCode': ['equal'], 'CountyName': ['equal'], 'PhoneNumber': ['equal'], 'HospitalType': ['equal'], 'HospitalOwner': ['equal'], 'EmergencyService': ['equal'], 'Condition': ['equal'], 'MeasureCode': ['equal'], 'MeasureName': ['equal'], 'Score': ['equal'], 'Sample': ['equal'], 'Stateavg': ['equal']}
# INFO:profiler.data.dataset:(possible types: numeric, categorical, text, date)
# INFO:profiler.data.dataset:(possible operators: equal, notequal, greater_than, less_than)
# INFO:profiler.data.dataset:inferred operators of attributes: {'ProviderNumber': ['equal'], 'HospitalName': ['equal'], 'Address1': ['equal'], 'City': ['equal'], 'State': ['equal'], 'ZipCode': ['equal'], 'CountyName': ['equal'], 'PhoneNumber': ['equal'], 'HospitalType': ['equal'], 'HospitalOwner': ['equal'], 'EmergencyService': ['equal'], 'Condition': ['equal'], 'MeasureCode': ['equal'], 'MeasureName': ['equal'], 'Score': ['equal'], 'Sample': ['equal'], 'Stateavg': ['equal']}
# INFO:profiler.utility:[0.04878091812133789] Load Data execution time: 0.04871082305908203
#
# INFO:profiler.data.dataset:(possible operators: equal, notequal, greater_than, less_than)
# INFO:profiler.data.dataset:updated types of ProviderNumber to 'categorical'
# INFO:profiler.utility:[0.04878091812133789] Load Data execution time: 0.04871082305908203
#
# INFO:profiler.data.dataset:updated operators of ProviderNumber to ['equal']
# INFO:profiler.data.dataset:updated types of ProviderNumber to 'categorical'
# INFO:profiler.data.dataset:updated types of ZipCode to 'numeric'
# INFO:profiler.data.dataset:updated operators of ProviderNumber to ['equal']
# INFO:profiler.data.dataset:updated operators of ZipCode to ['equal']
# INFO:profiler.data.dataset:updated types of ZipCode to 'numeric'
# INFO:profiler.data.dataset:updated types of PhoneNumber to 'categorical'
# INFO:profiler.data.dataset:updated operators of ZipCode to ['equal']
# INFO:profiler.data.dataset:updated operators of PhoneNumber to ['equal']
# INFO:profiler.data.dataset:updated types of PhoneNumber to 'categorical'
# INFO:profiler.data.dataset:updated types of State to 'text'
# INFO:profiler.data.dataset:updated operators of PhoneNumber to ['equal']
# INFO:profiler.data.dataset:updated operators of State to ['equal']
# INFO:profiler.data.dataset:updated types of State to 'text'
# INFO:profiler.data.dataset:updated types of EmergencyService to 'text'
# INFO:profiler.data.dataset:updated operators of State to ['equal']
# INFO:profiler.data.dataset:updated operators of EmergencyService to ['equal']
# INFO:profiler.data.dataset:updated types of EmergencyService to 'text'
# INFO:profiler.data.dataset:updated types of Score to 'numeric'
# INFO:profiler.data.dataset:updated operators of EmergencyService to ['equal']
# INFO:profiler.data.dataset:updated operators of Score to ['equal']
# INFO:profiler.data.dataset:updated types of Score to 'numeric'
# INFO:profiler.data.dataset:updated types of Sample to 'numeric'
# INFO:profiler.data.dataset:updated operators of Score to ['equal']
# INFO:profiler.data.dataset:updated operators of Sample to ['equal']
# INFO:profiler.data.dataset:updated types of Sample to 'numeric'
# INFO:profiler.data.dataset:updated inferred operators of attributes: {'ProviderNumber': ['equal'], 'HospitalName': ['equal'], 'Address1': ['equal'], 'City': ['equal'], 'State': ['equal'], 'ZipCode': ['equal'], 'CountyName': ['equal'], 'PhoneNumber': ['equal'], 'HospitalType': ['equal'], 'HospitalOwner': ['equal'], 'EmergencyService': ['equal'], 'Condition': ['equal'], 'MeasureCode': ['equal'], 'MeasureName': ['equal'], 'Score': ['equal'], 'Sample': ['equal'], 'Stateavg': ['equal']}
# INFO:profiler.data.dataset:updated operators of Sample to ['equal']
# INFO:profiler.data.dataset:updated inferred operators of attributes: {'ProviderNumber': ['equal'], 'HospitalName': ['equal'], 'Address1': ['equal'], 'City': ['equal'], 'State': ['equal'], 'ZipCode': ['equal'], 'CountyName': ['equal'], 'PhoneNumber': ['equal'], 'HospitalType': ['equal'], 'HospitalOwner': ['equal'], 'EmergencyService': ['equal'], 'Condition': ['equal'], 'MeasureCode': ['equal'], 'MeasureName': ['equal'], 'Score': ['equal'], 'Sample': ['equal'], 'Stateavg': ['equal']}

# %%
clean = pf2.session.ds.df['HospitalName']
dirty = pf.session.ds.df['HospitalName']
vec = pf.session.embed.models['HospitalName'].vec
vocab = pf.session.embed.models['HospitalName'].vocab

# %%
import pandas as pd

# %%
import sklearn
# 1. calculate cosine distances with all other values in the domain 
distance = sklearn.metrics.pairwise.cosine_distances(vec)

# %%
dis_with_same = []
dis_with_other = []
for i, cell in enumerate(vocab.index):
    if not isinstance(cell, np.str):
        continue
    # for each word, find the corresponding correct word in clean data
    clean_cell = clean.loc[dirty.index[dirty==cell][0]]
    # find the index of the words in dirty vocab that equals to this word in groudtruth
    variations = dirty[(clean==clean_cell) & (dirty != cell)]
    variations = np.unique(variations[~pd.isnull(variations)])
    if len(variations) == 0:
        continue
    print("cell: %s"%cell)
    similar_idx = vocab.loc[variations,'index'].values
    same_idx = [vocab.loc[cell, 'index']]
    dis_with_same.extend(distance[i, similar_idx])
    print("\n-- distance with variational representations of the word -- ")
    maxdis = -1
    for word, dis in zip(variations, distance[i, vocab.loc[variations, 'index']]):
        print("%s (%.4f)"%(word, dis))
        maxdis = max(dis, maxdis)
    
    nonsimilar_idx = np.array(list(set(vocab['index'].values) - set(similar_idx) - set(same_idx)))

    nonsimilar_dis = distance[i, nonsimilar_idx]
    dis_with_other.extend(nonsimilar_dis)
    print("\n-- nonsimilar words but with small distances --")
    for word, dis in zip(vocab.index.values[nonsimilar_idx[nonsimilar_dis<maxdis]], nonsimilar_dis[nonsimilar_dis<maxdis]):
        print("%s (%.4f)"%(word, dis))
    print("\n====")
# Out:
# cell: alaska regional hospital
#
# -- distance with variational representations of the word --
# xlxskx regionxl hospitxl (0.1121)
#
# -- nonsimilar words but with small distances --
# andalusia regional hospital (0.0311)
# andaluxia regional hoxpital (0.0767)
# andaxusia regionax hospitax (0.0849)
# baptist medical center south (0.0788)
# callahan eye foundation hospital (0.0734)
# cherokee medical center (0.0708)
# chilton medical center (0.0741)
# community hospital inc (0.1115)
# coosa valley medical center (0.0747)
# crenshaw community hospital (0.0773)
# cullman regional medical center (0.0500)
# cullmxn regionxl medicxl center (0.0766)
# dale medical center (0.0891)
# decatur general hospital (0.0887)
# dekalb regional medical center (0.0518)
# dexalb regional medical center (0.0484)
# east alabama medical center and snf (0.0766)
# elba general hospital (0.0933)
# eliza coffee memorial hospital (0.0621)
# fayette medical center (0.0813)
# flowers hospital (0.0910)
# floxers hospital (0.0722)
# gadsden regional medical center (0.0465)
# georgiana hospital (0.0728)
# georgiaxa hospital (0.0594)
# hartselle medical center (0.0761)
# helen keller memorial hospital (0.0623)
# huntsville hospital (0.0702)
# marion regional medical center (0.0537)
# marshall medical center north (0.0821)
# marshall medical center south (0.0723)
# medical center enterprise (0.0615)
# mizell memorial hospital (0.0649)
# northwest medical center (0.0687)
# prattville baptist hospital (0.0744)
# riverview regional medical center (0.0428)
# riverview rexional medical center (0.0566)
# russellville hospital (0.0656)
# shelby baptist medical center (0.0831)
# southeast alabama medical center (0.0505)
# southeast alabama medxcal center (0.0696)
# southwest alabama medical center (0.0535)
# stringfellow memorial hospital (0.0574)
# univ of south alabama medical center (0.0805)
# univ ox south alabama medical center (0.0828)
# university of alabama hospital (0.0876)
# wedowee hospital (0.0866)
# xivexview xegional medical centex (0.0613)
# xniv of soxth alabama medical center (0.1091)
# yukon kuskokwim delta reg hospital (0.1098)
#
# ====
# cell: andalusia regional hospital
#
# -- distance with variational representations of the word --
# andaluxia regional hoxpital (0.0529)
# andaxusia regionax hospitax (0.0768)
#
# -- nonsimilar words but with small distances --
# alaska regional hospital (0.0311)
# callahan eye foundation hospital (0.0735)
# cullman regional medical center (0.0541)
# dekalb regional medical center (0.0605)
# dexalb regional medical center (0.0572)
# eliza coffee memorial hospital (0.0625)
# floxers hospital (0.0707)
# gadsden regional medical center (0.0495)
# georgiana hospital (0.0707)
# georgiaxa hospital (0.0618)
# helen keller memorial hospital (0.0600)
# huntsville hospital (0.0659)
# marion regional medical center (0.0572)
# medical center enterprise (0.0720)
# mizell memorial hospital (0.0521)
# prattville baptist hospital (0.0715)
# riverview regional medical center (0.0497)
# riverview rexional medical center (0.0631)
# russellville hospital (0.0692)
# southeast alabama medical center (0.0694)
# southwest alabama medical center (0.0742)
# stringfellow memorial hospital (0.0526)
# xivexview xegional medical centex (0.0652)
#
# ====
# cell: andaluxia regional hoxpital
#
# -- distance with variational representations of the word --
# andalusia regional hospital (0.0529)
# andaxusia regionax hospitax (0.1374)
#
# -- nonsimilar words but with small distances --
# alaska regional hospital (0.0767)
# baptist medical center south (0.1298)
# callahan eye foundation hospital (0.1298)
# cherokee medical center (0.1305)
# chilton medical center (0.1269)
# coosa valley medical center (0.1289)
# cullman regional medical center (0.0872)
# cullmxn regionxl medicxl center (0.1372)
# dale medical center (0.1255)
# dekalb regional medical center (0.0943)
# dexalb regional medical center (0.0897)
# east alabama medical center and snf (0.1228)
# eliza coffee memorial hospital (0.1206)
# fayette medical center (0.1329)
# gadsden regional medical center (0.0857)
# georgiana hospital (0.1348)
# georgiaxa hospital (0.1239)
# hartselle medical center (0.1350)
# helen keller memorial hospital (0.1196)
# huntsville hospital (0.1330)
# marion regional medical center (0.0972)
# marshall medical center south (0.1345)
# medical center enterprise (0.1185)
# mizell memorial hospital (0.1149)
# northwest medical center (0.1335)
# prattville baptist hospital (0.1242)
# riverview regional medical center (0.0853)
# riverview rexional medical center (0.0988)
# russellville hospital (0.1334)
# shelby baptist medical center (0.1317)
# southeast alabama medical center (0.1205)
# southwest alabama medical center (0.1231)
# stringfellow memorial hospital (0.1170)
# univ of south alabama medical center (0.1319)
# univ ox south alabama medical center (0.1333)
# xivexview xegional medical centex (0.0909)
#
# ====
# cell: andaxusia regionax hospitax
#
# -- distance with variational representations of the word --
# andalusia regional hospital (0.0768)
# andaluxia regional hoxpital (0.1374)
#
# -- nonsimilar words but with small distances --
# alaska regional hospital (0.0849)
# cherokee medical center (0.1364)
# chilton medical center (0.1327)
# coosa valley medical center (0.1338)
# crenshaw community hospital (0.1249)
# cullman regional medical center (0.1104)
# dekalb regional medical center (0.1153)
# dexalb regional medical center (0.1085)
# east alabama medical center and snf (0.1328)
# eliza coffee memorial hospital (0.1239)
# floxers hospital (0.1237)
# gadsden regional medical center (0.1136)
# georgiana hospital (0.1213)
# georgiaxa hospital (0.1069)
# helen keller memorial hospital (0.1089)
# huntsville hospital (0.1067)
# marion regional medical center (0.1151)
# medical center enterprise (0.1281)
# mizell memorial hospital (0.1079)
# riverview regional medical center (0.1077)
# riverview rexional medical center (0.1238)
# russellville hospital (0.1144)
# southeast alabama medical center (0.1098)
# southwest alabama medical center (0.1188)
# stringfellow memorial hospital (0.1010)
# univ of south alabama medical center (0.1268)
# univ ox south alabama medical center (0.1369)
# university of alabama hospital (0.1253)
# xivexview xegional medical centex (0.1268)
#
# ====
# cell: baptist medical center south
#
# -- distance with variational representations of the word --
# baptist medical cexter south (0.0303)
#
# -- nonsimilar words but with small distances --
# marshall medical center south (0.0153)
#
# ====
# cell: baptist medical cexter south
#
# -- distance with variational representations of the word --
# baptist medical center south (0.0303)
#
# -- nonsimilar words but with small distances --
#
# ====
# cell: communitx hospital inc
#
# -- distance with variational representations of the word --
# community hospital inc (0.0059)
# communixy hospixal inc (0.0526)
#
# -- nonsimilar words but with small distances --
#
# ====
# cell: community hospital inc
#
# -- distance with variational representations of the word --
# communitx hospital inc (0.0059)
# communixy hospixal inc (0.0489)
#
# -- nonsimilar words but with small distances --
#
# ====
# cell: communixy hospixal inc
#
# -- distance with variational representations of the word --
# communitx hospital inc (0.0526)
# community hospital inc (0.0489)
#
# -- nonsimilar words but with small distances --
#
# ====
# cell: crenshaw community hospital
#
# -- distance with variational representations of the word --
# crenshaw cxmmunity hxspital (0.0812)
#
# -- nonsimilar words but with small distances --
# alaska regional hospital (0.0773)
# community hospital inc (0.0786)
# floxers hospital (0.0764)
# georgiaxa hospital (0.0754)
# helen keller memorial hospital (0.0747)
# huntsville hospital (0.0793)
# stringfellow memorial hospital (0.0671)
#
# ====
# cell: crenshaw cxmmunity hxspital
#
# -- distance with variational representations of the word --
# crenshaw community hospital (0.0812)
#
# -- nonsimilar words but with small distances --
#
# ====
# cell: cullman regional medical center
#
# -- distance with variational representations of the word --
# cullmxn regionxl medicxl center (0.0433)
#
# -- nonsimilar words but with small distances --
# baptist medical center south (0.0419)
# cherokee medical center (0.0300)
# chilton medical center (0.0321)
# dale medical center (0.0421)
# dekalb regional medical center (0.0199)
# dexalb regional medical center (0.0171)
# fayette medical center (0.0320)
# gadsden regional medical center (0.0139)
# hartselle medical center (0.0334)
# marion regional medical center (0.0206)
# marshall medical center south (0.0409)
# medical center enterprise (0.0219)
# northwest medical center (0.0291)
# riverview regional medical center (0.0135)
# riverview rexional medical center (0.0271)
# shelby baptist medical center (0.0369)
# southeast alabama medical center (0.0293)
# southwest alabama medical center (0.0318)
# xivexview xegional medical centex (0.0379)
#
# ====
# cell: cullmxn regionxl medicxl center
#
# -- distance with variational representations of the word --
# cullman regional medical center (0.0433)
#
# -- nonsimilar words but with small distances --
#
# ====
# cell: dekalb regional medical center
#
# -- distance with variational representations of the word --
# dexalb regional medical center (0.0212)
#
# -- nonsimilar words but with small distances --
# cullman regional medical center (0.0199)
# gadsden regional medical center (0.0206)
# riverview regional medical center (0.0189)
#
# ====
# cell: dexalb regional medical center
#
# -- distance with variational representations of the word --
# dekalb regional medical center (0.0212)
#
# -- nonsimilar words but with small distances --
# cullman regional medical center (0.0171)
# gadsden regional medical center (0.0194)
# riverview regional medical center (0.0175)
#
# ====
# cell: flowers hospital
#
# -- distance with variational representations of the word --
# floxers hospital (0.0573)
#
# -- nonsimilar words but with small distances --
#
# ====
# cell: floxers hospital
#
# -- distance with variational representations of the word --
# flowers hospital (0.0573)
#
# -- nonsimilar words but with small distances --
# stringfellow memorial hospital (0.0525)
#
# ====
# cell: georgiana hospital
#
# -- distance with variational representations of the word --
# georgiaxa hospital (0.0264)
#
# -- nonsimilar words but with small distances --
#
# ====
# cell: georgiaxa hospital
#
# -- distance with variational representations of the word --
# georgiana hospital (0.0264)
#
# -- nonsimilar words but with small distances --
#
# ====
# cell: huntsville hospital
#
# -- distance with variational representations of the word --
# huntsvxlle hospxtal (0.1903)
#
# -- nonsimilar words but with small distances --
# alaska regional hospital (0.0702)
# andalusia regional hospital (0.0659)
# andaluxia regional hoxpital (0.1330)
# andaxusia regionax hospitax (0.1067)
# baptist medical center south (0.1216)
# baptist medical cexter south (0.1534)
# callahan eye foundation hospital (0.0837)
# cherokee medical center (0.1150)
# chilton medical center (0.1222)
# communitx hospital inc (0.1026)
# community hospital inc (0.0992)
# coosa valley medical center (0.1091)
# crenshaw community hospital (0.0793)
# crenshaw cxmmunity hxspital (0.1751)
# cullman regional medical center (0.1068)
# cullmxn regionxl medicxl center (0.1514)
# dale medical center (0.1348)
# decatur general hospital (0.0792)
# dekalb regional medical center (0.1088)
# dexalb regional medical center (0.1056)
# east alabama medical center and snf (0.0955)
# elba general hospital (0.1086)
# eliza coffee memorial hospital (0.0746)
# fayette medical center (0.1174)
# flowers hospital (0.0719)
# floxers hospital (0.0581)
# g h lanier memorial hospital (0.1454)
# gadsden regional medical center (0.0995)
# georgiana hospital (0.0634)
# georgiaxa hospital (0.0585)
# hartselle medical center (0.1075)
# helen keller memorial hospital (0.0777)
# jackson hospital & clinic inc (0.1241)
# jaxkson hospital & xlinix inx (0.1743)
# marion regional medical center (0.1160)
# marshall medical center north (0.1033)
# marshall medical center south (0.1167)
# marshall medical cenxer norxh (0.1561)
# medical center enterprise (0.1032)
# medixal xenter enterprise (0.1540)
# medxcal center enterprxse (0.1817)
# mizell memorial hospital (0.0598)
# northwest medical center (0.1011)
# prattville baptist hospital (0.0619)
# riverview regional medical center (0.1088)
# riverview rexional medical center (0.1173)
# russellville hospital (0.0388)
# shelby baptist medical center (0.1230)
# southeast alabama medical center (0.0978)
# southeast alabama medxcal center (0.1324)
# southwest alabama medical center (0.0999)
# st vincents hospital (0.1566)
# stringfellow memorial hospital (0.0584)
# univ of south alabama medical center (0.1185)
# univ ox south alabama medical center (0.1219)
# university of alabama hospital (0.0896)
# wedowee hospital (0.0800)
# xivexview xegional medical centex (0.1186)
# xlxskx regionxl hospitxl (0.1503)
# xniv of soxth alabama medical center (0.1342)
# yukon kuskokwim delta reg hospital (0.1298)
#
# ====
# cell: huntsvxlle hospxtal
#
# -- distance with variational representations of the word --
# huntsville hospital (0.1903)
#
# -- nonsimilar words but with small distances --
#
# ====
# cell: jackson hospital & clinic inc
#
# -- distance with variational representations of the word --
# jaxkson hospital & xlinix inx (0.0848)
#
# -- nonsimilar words but with small distances --
# communitx hospital inc (0.0795)
# community hospital inc (0.0817)
#
# ====
# cell: jaxkson hospital & xlinix inx
#
# -- distance with variational representations of the word --
# jackson hospital & clinic inc (0.0848)
#
# -- nonsimilar words but with small distances --
#
# ====
# cell: marshall medical center north
#
# -- distance with variational representations of the word --
# marshall medical cenxer norxh (0.0702)
#
# -- nonsimilar words but with small distances --
# baptist medical center south (0.0562)
# cherokee medical center (0.0397)
# chilton medical center (0.0429)
# coosa valley medical center (0.0466)
# cullman regional medical center (0.0490)
# dale medical center (0.0586)
# dekalb regional medical center (0.0544)
# dexalb regional medical center (0.0587)
# fayette medical center (0.0366)
# gadsden regional medical center (0.0463)
# hartselle medical center (0.0352)
# marion regional medical center (0.0471)
# marshall medical center south (0.0351)
# medical center enterprise (0.0360)
# northwest medical center (0.0263)
# riverview regional medical center (0.0483)
# riverview rexional medical center (0.0508)
# shelby baptist medical center (0.0531)
# southeast alabama medical center (0.0365)
# southeast alabama medxcal center (0.0563)
# southwest alabama medical center (0.0412)
# xivexview xegional medical centex (0.0572)
#
# ====
# cell: marshall medical cenxer norxh
#
# -- distance with variational representations of the word --
# marshall medical center north (0.0702)
#
# -- nonsimilar words but with small distances --
#
# ====
# cell: medical center enterprise
#
# -- distance with variational representations of the word --
# medixal xenter enterprise (0.0705)
# medxcal center enterprxse (0.0504)
#
# -- nonsimilar words but with small distances --
# alaska regional hospital (0.0615)
# baptist medical center south (0.0393)
# cherokee medical center (0.0199)
# chilton medical center (0.0208)
# coosa valley medical center (0.0378)
# cullman regional medical center (0.0219)
# cullmxn regionxl medicxl center (0.0504)
# dale medical center (0.0397)
# dekalb regional medical center (0.0315)
# dexalb regional medical center (0.0281)
# east alabama medical center and snf (0.0598)
# fayette medical center (0.0248)
# gadsden regional medical center (0.0240)
# hartselle medical center (0.0198)
# marion regional medical center (0.0313)
# marshall medical center north (0.0360)
# marshall medical center south (0.0350)
# northwest medical center (0.0172)
# riverview regional medical center (0.0219)
# riverview rexional medical center (0.0277)
# shelby baptist medical center (0.0360)
# southeast alabama medical center (0.0207)
# southeast alabama medxcal center (0.0386)
# southwest alabama medical center (0.0227)
# univ of south alabama medical center (0.0520)
# xivexview xegional medical centex (0.0414)
# xniv of soxth alabama medical center (0.0663)
#
# ====
# cell: medixal xenter enterprise
#
# -- distance with variational representations of the word --
# medical center enterprise (0.0705)
# medxcal center enterprxse (0.0904)
#
# -- nonsimilar words but with small distances --
#
# ====
# cell: medxcal center enterprxse
#
# -- distance with variational representations of the word --
# medical center enterprise (0.0504)
# medixal xenter enterprise (0.0904)
#
# -- nonsimilar words but with small distances --
# baptist medical center south (0.0904)
# cherokee medical center (0.0681)
# chilton medical center (0.0786)
# cullman regional medical center (0.0716)
# dale medical center (0.0812)
# dekalb regional medical center (0.0840)
# dexalb regional medical center (0.0817)
# fayette medical center (0.0697)
# gadsden regional medical center (0.0762)
# hartselle medical center (0.0706)
# marion regional medical center (0.0762)
# marshall medical center north (0.0897)
# marshall medical center south (0.0895)
# northwest medical center (0.0620)
# riverview regional medical center (0.0648)
# riverview rexional medical center (0.0679)
# shelby baptist medical center (0.0897)
# southeast alabama medical center (0.0753)
# southeast alabama medxcal center (0.0492)
# southwest alabama medical center (0.0754)
# xivexview xegional medical centex (0.0844)
#
# ====
# cell: riverview regional medical center
#
# -- distance with variational representations of the word --
# riverview rexional medical center (0.0087)
# rivxrvixw rxgional mxdical cxntxr (0.2090)
# xivexview xegional medical centex (0.0262)
#
# -- nonsimilar words but with small distances --
# alaska regional hospital (0.0428)
# andalusia regional hospital (0.0497)
# andaluxia regional hoxpital (0.0853)
# andaxusia regionax hospitax (0.1077)
# baptist medical center south (0.0460)
# baptist medical cexter south (0.0932)
# callahan eye foundation hospital (0.0998)
# cherokee medical center (0.0293)
# chilton medical center (0.0306)
# communitx hospital inc (0.1355)
# community hospital inc (0.1332)
# coosa valley medical center (0.0422)
# crenshaw community hospital (0.1166)
# crenshaw cxmmunity hxspital (0.1967)
# cullman regional medical center (0.0135)
# cullmxn regionxl medicxl center (0.0471)
# dale medical center (0.0441)
# decatur general hospital (0.1153)
# dekalb regional medical center (0.0189)
# dexalb regional medical center (0.0175)
# east alabama medical center and snf (0.0624)
# elba general hospital (0.1243)
# eliza coffee memorial hospital (0.0838)
# fayette medical center (0.0318)
# flowers hospital (0.1487)
# floxers hospital (0.1073)
# g h lanier memorial hospital (0.1465)
# gadsden regional medical center (0.0120)
# georgiana hospital (0.1109)
# georgiaxa hospital (0.0892)
# hartselle medical center (0.0323)
# helen keller memorial hospital (0.0801)
# huntsville hospital (0.1088)
# jackson hospital & clinic inc (0.1865)
# marion regional medical center (0.0216)
# marshall medical center north (0.0483)
# marshall medical center south (0.0422)
# marshall medical cenxer norxh (0.1006)
# medical center enterprise (0.0219)
# medixal xenter enterprise (0.0964)
# medxcal center enterprxse (0.0648)
# mizell memorial hospital (0.0908)
# northwest medical center (0.0280)
# prattville baptist hospital (0.0929)
# russellville hospital (0.1080)
# shelby baptist medical center (0.0391)
# southeast alabama medical center (0.0288)
# southeast alabama medxcal center (0.0480)
# southwest alabama medical center (0.0319)
# st vincents hospital (0.1232)
# stringfellow memorial hospital (0.0772)
# univ of south alabama medical center (0.0613)
# univ ox south alabama medical center (0.0753)
# university of alabama hospital (0.1022)
# wedowee hospital (0.1399)
# xlxskx regionxl hospitxl (0.1298)
# xniv of soxth alabama medical center (0.0757)
# yukon kuskokwim delta reg hospital (0.1285)
#
# ====
# cell: riverview rexional medical center
#
# -- distance with variational representations of the word --
# riverview regional medical center (0.0087)
# rivxrvixw rxgional mxdical cxntxr (0.2069)
# xivexview xegional medical centex (0.0323)
#
# -- nonsimilar words but with small distances --
# alaska regional hospital (0.0566)
# andalusia regional hospital (0.0631)
# andaluxia regional hoxpital (0.0988)
# andaxusia regionax hospitax (0.1238)
# baptist medical center south (0.0479)
# baptist medical cexter south (0.0886)
# callahan eye foundation hospital (0.1002)
# cherokee medical center (0.0344)
# chilton medical center (0.0327)
# communitx hospital inc (0.1365)
# community hospital inc (0.1360)
# coosa valley medical center (0.0456)
# crenshaw community hospital (0.1286)
# cullman regional medical center (0.0271)
# cullmxn regionxl medicxl center (0.0597)
# dale medical center (0.0467)
# decatur general hospital (0.1134)
# dekalb regional medical center (0.0294)
# dexalb regional medical center (0.0307)
# east alabama medical center and snf (0.0737)
# elba general hospital (0.1293)
# eliza coffee memorial hospital (0.0962)
# fayette medical center (0.0317)
# flowers hospital (0.1515)
# floxers hospital (0.1131)
# g h lanier memorial hospital (0.1478)
# gadsden regional medical center (0.0231)
# georgiana hospital (0.1110)
# georgiaxa hospital (0.0881)
# hartselle medical center (0.0399)
# helen keller memorial hospital (0.0894)
# huntsville hospital (0.1173)
# jackson hospital & clinic inc (0.1878)
# marion regional medical center (0.0322)
# marshall medical center north (0.0508)
# marshall medical center south (0.0477)
# marshall medical cenxer norxh (0.1022)
# medical center enterprise (0.0277)
# medixal xenter enterprise (0.1010)
# medxcal center enterprxse (0.0679)
# mizell memorial hospital (0.0946)
# northwest medical center (0.0314)
# prattville baptist hospital (0.0980)
# russellville hospital (0.1133)
# shelby baptist medical center (0.0423)
# southeast alabama medical center (0.0347)
# southeast alabama medxcal center (0.0527)
# southwest alabama medical center (0.0391)
# st vincents hospital (0.1286)
# stringfellow memorial hospital (0.0794)
# univ of south alabama medical center (0.0693)
# univ ox south alabama medical center (0.0852)
# university of alabama hospital (0.1109)
# wedowee hospital (0.1479)
# xlxskx regionxl hospitxl (0.1434)
# xniv of soxth alabama medical center (0.0820)
# yukon kuskokwim delta reg hospital (0.1348)
#
# ====
# cell: rivxrvixw rxgional mxdical cxntxrcell: alaska regional hospital
#
# -- distance with variational representations of the word --
# xlxskx regionxl hospitxl (0.1121)
#
# -- nonsimilar words but with small distances --
# andalusia regional hospital (0.0311)
# andaluxia regional hoxpital (0.0767)
# andaxusia regionax hospitax (0.0849)
# baptist medical center south (0.0788)
# callahan eye foundation hospital (0.0734)
# cherokee medical center (0.0708)
# chilton medical center (0.0741)
# community hospital inc (0.1115)
# coosa valley medical center (0.0747)
# crenshaw community hospital (0.0773)
# cullman regional medical center (0.0500)
# cullmxn regionxl medicxl center (0.0766)
# dale medical center (0.0891)
# decatur general hospital (0.0887)
# dekalb regional medical center (0.0518)
# dexalb regional medical center (0.0484)
# east alabama medical center and snf (0.0766)
# elba general hospital (0.0933)
# eliza coffee memorial hospital (0.0621)
# fayette medical center (0.0813)
# flowers hospital (0.0910)
# floxers hospital (0.0722)
# gadsden regional medical center (0.0465)
# georgiana hospital (0.0728)
# georgiaxa hospital (0.0594)
# hartselle medical center (0.0761)
# helen keller memorial hospital (0.0623)
# huntsville hospital (0.0702)
# marion regional medical center (0.0537)
# marshall medical center north (0.0821)
# marshall medical center south (0.0723)
# medical center enterprise (0.0615)
# mizell memorial hospital (0.0649)
# northwest medical center (0.0687)
# prattville baptist hospital (0.0744)
# riverview regional medical center (0.0428)
# riverview rexional medical center (0.0566)
# russellville hospital (0.0656)
# shelby baptist medical center (0.0831)
# southeast alabama medical center (0.0505)
# southeast alabama medxcal center (0.0696)
# southwest alabama medical center (0.0535)
# stringfellow memorial hospital (0.0574)
# univ of south alabama medical center (0.0805)
# univ ox south alabama medical center (0.0828)
# university of alabama hospital (0.0876)
# wedowee hospital (0.0866)
# xivexview xegional medical centex (0.0613)
# xniv of soxth alabama medical center (0.1091)
# yukon kuskokwim delta reg hospital (0.1098)
#
# ====
# cell: andalusia regional hospital
#
# -- distance with variational representations of the word --
# andaluxia regional hoxpital (0.0529)
# andaxusia regionax hospitax (0.0768)
#
# -- nonsimilar words but with small distances --
# alaska regional hospital (0.0311)
# callahan eye foundation hospital (0.0735)
# cullman regional medical center (0.0541)
# dekalb regional medical center (0.0605)
# dexalb regional medical center (0.0572)
# eliza coffee memorial hospital (0.0625)
# floxers hospital (0.0707)
# gadsden regional medical center (0.0495)
# georgiana hospital (0.0707)
# georgiaxa hospital (0.0618)
# helen keller memorial hospital (0.0600)
# huntsville hospital (0.0659)
# marion regional medical center (0.0572)
# medical center enterprise (0.0720)
# mizell memorial hospital (0.0521)
# prattville baptist hospital (0.0715)
# riverview regional medical center (0.0497)
# riverview rexional medical center (0.0631)
# russellville hospital (0.0692)
# southeast alabama medical center (0.0694)
# southwest alabama medical center (0.0742)
# stringfellow memorial hospital (0.0526)
# xivexview xegional medical centex (0.0652)
#
# ====
# cell: andaluxia regional hoxpital
#
# -- distance with variational representations of the word --
# andalusia regional hospital (0.0529)
# andaxusia regionax hospitax (0.1374)
#
# -- nonsimilar words but with small distances --
# alaska regional hospital (0.0767)
# baptist medical center south (0.1298)
# callahan eye foundation hospital (0.1298)
# cherokee medical center (0.1305)
# chilton medical center (0.1269)
# coosa valley medical center (0.1289)
# cullman regional medical center (0.0872)
# cullmxn regionxl medicxl center (0.1372)
# dale medical center (0.1255)
# dekalb regional medical center (0.0943)
# dexalb regional medical center (0.0897)
# east alabama medical center and snf (0.1228)
# eliza coffee memorial hospital (0.1206)
# fayette medical center (0.1329)
# gadsden regional medical center (0.0857)
# georgiana hospital (0.1348)
# georgiaxa hospital (0.1239)
# hartselle medical center (0.1350)
# helen keller memorial hospital (0.1196)
# huntsville hospital (0.1330)
# marion regional medical center (0.0972)
# marshall medical center south (0.1345)
# medical center enterprise (0.1185)
# mizell memorial hospital (0.1149)
# northwest medical center (0.1335)
# prattville baptist hospital (0.1242)
# riverview regional medical center (0.0853)
# riverview rexional medical center (0.0988)
# russellville hospital (0.1334)
# shelby baptist medical center (0.1317)
# southeast alabama medical center (0.1205)
# southwest alabama medical center (0.1231)
# stringfellow memorial hospital (0.1170)
# univ of south alabama medical center (0.1319)
# univ ox south alabama medical center (0.1333)
# xivexview xegional medical centex (0.0909)
#
# ====
# cell: andaxusia regionax hospitax
#
# -- distance with variational representations of the word --
# andalusia regional hospital (0.0768)
# andaluxia regional hoxpital (0.1374)
#
# -- nonsimilar words but with small distances --
# alaska regional hospital (0.0849)
# cherokee medical center (0.1364)
# chilton medical center (0.1327)
# coosa valley medical center (0.1338)
# crenshaw community hospital (0.1249)
# cullman regional medical center (0.1104)
# dekalb regional medical center (0.1153)
# dexalb regional medical center (0.1085)
# east alabama medical center and snf (0.1328)
# eliza coffee memorial hospital (0.1239)
# floxers hospital (0.1237)
# gadsden regional medical center (0.1136)
# georgiana hospital (0.1213)
# georgiaxa hospital (0.1069)
# helen keller memorial hospital (0.1089)
# huntsville hospital (0.1067)
# marion regional medical center (0.1151)
# medical center enterprise (0.1281)
# mizell memorial hospital (0.1079)
# riverview regional medical center (0.1077)
# riverview rexional medical center (0.1238)
# russellville hospital (0.1144)
# southeast alabama medical center (0.1098)
# southwest alabama medical center (0.1188)
# stringfellow memorial hospital (0.1010)
# univ of south alabama medical center (0.1268)
# univ ox south alabama medical center (0.1369)
# university of alabama hospital (0.1253)
# xivexview xegional medical centex (0.1268)
#
# ====
# cell: baptist medical center south
#
# -- distance with variational representations of the word --
# baptist medical cexter south (0.0303)
#
# -- nonsimilar words but with small distances --
# marshall medical center south (0.0153)
#
# ====
# cell: baptist medical cexter south
#
# -- distance with variational representations of the word --
# baptist medical center south (0.0303)
#
# -- nonsimilar words but with small distances --
#
# ====
# cell: communitx hospital inc
#
# -- distance with variational representations of the word --
# community hospital inc (0.0059)
# communixy hospixal inc (0.0526)
#
# -- nonsimilar words but with small distances --
#
# ====
# cell: community hospital inc
#
# -- distance with variational representations of the word --
# communitx hospital inc (0.0059)
# communixy hospixal inc (0.0489)
#
# -- nonsimilar words but with small distances --
#
# ====
# cell: communixy hospixal inc
#
# -- distance with variational representations of the word --
# communitx hospital inc (0.0526)
# community hospital inc (0.0489)
#
# -- nonsimilar words but with small distances --
#
# ====
# cell: crenshaw community hospital
#
# -- distance with variational representations of the word --
# crenshaw cxmmunity hxspital (0.0812)
#
# -- nonsimilar words but with small distances --
# alaska regional hospital (0.0773)
# community hospital inc (0.0786)
# floxers hospital (0.0764)
# georgiaxa hospital (0.0754)
# helen keller memorial hospital (0.0747)
# huntsville hospital (0.0793)
# stringfellow memorial hospital (0.0671)
#
# ====
# cell: crenshaw cxmmunity hxspital
#
# -- distance with variational representations of the word --
# crenshaw community hospital (0.0812)
#
# -- nonsimilar words but with small distances --
#
# ====
# cell: cullman regional medical center
#
# -- distance with variational representations of the word --
# cullmxn regionxl medicxl center (0.0433)
#
# -- nonsimilar words but with small distances --
# baptist medical center south (0.0419)
# cherokee medical center (0.0300)
# chilton medical center (0.0321)
# dale medical center (0.0421)
# dekalb regional medical center (0.0199)
# dexalb regional medical center (0.0171)
# fayette medical center (0.0320)
# gadsden regional medical center (0.0139)
# hartselle medical center (0.0334)
# marion regional medical center (0.0206)
# marshall medical center south (0.0409)
# medical center enterprise (0.0219)
# northwest medical center (0.0291)
# riverview regional medical center (0.0135)
# riverview rexional medical center (0.0271)
# shelby baptist medical center (0.0369)
# southeast alabama medical center (0.0293)
# southwest alabama medical center (0.0318)
# xivexview xegional medical centex (0.0379)
#
# ====
# cell: cullmxn regionxl medicxl center
#
# -- distance with variational representations of the word --
# cullman regional medical center (0.0433)
#
# -- nonsimilar words but with small distances --
#
# ====
# cell: dekalb regional medical center
#
# -- distance with variational representations of the word --
# dexalb regional medical center (0.0212)
#
# -- nonsimilar words but with small distances --
# cullman regional medical center (0.0199)
# gadsden regional medical center (0.0206)
# riverview regional medical center (0.0189)
#
# ====
# cell: dexalb regional medical center
#
# -- distance with variational representations of the word --
# dekalb regional medical center (0.0212)
#
# -- nonsimilar words but with small distances --
# cullman regional medical center (0.0171)
# gadsden regional medical center (0.0194)
# riverview regional medical center (0.0175)
#
# ====
# cell: flowers hospital
#
# -- distance with variational representations of the word --
# floxers hospital (0.0573)
#
# -- nonsimilar words but with small distances --
#
# ====
# cell: floxers hospital
#
# -- distance with variational representations of the word --
# flowers hospital (0.0573)
#
# -- nonsimilar words but with small distances --
# stringfellow memorial hospital (0.0525)
#
# ====
# cell: georgiana hospital
#
# -- distance with variational representations of the word --
# georgiaxa hospital (0.0264)
#
# -- nonsimilar words but with small distances --
#
# ====
# cell: georgiaxa hospital
#
# -- distance with variational representations of the word --
# georgiana hospital (0.0264)
#
# -- nonsimilar words but with small distances --
#
# ====
# cell: huntsville hospital
#
# -- distance with variational representations of the word --
# huntsvxlle hospxtal (0.1903)
#
# -- nonsimilar words but with small distances --
# alaska regional hospital (0.0702)
# andalusia regional hospital (0.0659)
# andaluxia regional hoxpital (0.1330)
# andaxusia regionax hospitax (0.1067)
# baptist medical center south (0.1216)
# baptist medical cexter south (0.1534)
# callahan eye foundation hospital (0.0837)
# cherokee medical center (0.1150)
# chilton medical center (0.1222)
# communitx hospital inc (0.1026)
# community hospital inc (0.0992)
# coosa valley medical center (0.1091)
# crenshaw community hospital (0.0793)
# crenshaw cxmmunity hxspital (0.1751)
# cullman regional medical center (0.1068)
# cullmxn regionxl medicxl center (0.1514)
# dale medical center (0.1348)
# decatur general hospital (0.0792)
# dekalb regional medical center (0.1088)
# dexalb regional medical center (0.1056)
# east alabama medical center and snf (0.0955)
# elba general hospital (0.1086)
# eliza coffee memorial hospital (0.0746)
# fayette medical center (0.1174)
# flowers hospital (0.0719)
# floxers hospital (0.0581)
# g h lanier memorial hospital (0.1454)
# gadsden regional medical center (0.0995)
# georgiana hospital (0.0634)
# georgiaxa hospital (0.0585)
# hartselle medical center (0.1075)
# helen keller memorial hospital (0.0777)
# jackson hospital & clinic inc (0.1241)
# jaxkson hospital & xlinix inx (0.1743)
# marion regional medical center (0.1160)
# marshall medical center north (0.1033)
# marshall medical center south (0.1167)
# marshall medical cenxer norxh (0.1561)
# medical center enterprise (0.1032)
# medixal xenter enterprise (0.1540)
# medxcal center enterprxse (0.1817)
# mizell memorial hospital (0.0598)
# northwest medical center (0.1011)
# prattville baptist hospital (0.0619)
# riverview regional medical center (0.1088)
# riverview rexional medical center (0.1173)
# russellville hospital (0.0388)
# shelby baptist medical center (0.1230)
# southeast alabama medical center (0.0978)
# southeast alabama medxcal center (0.1324)
# southwest alabama medical center (0.0999)
# st vincents hospital (0.1566)
# stringfellow memorial hospital (0.0584)
# univ of south alabama medical center (0.1185)
# univ ox south alabama medical center (0.1219)
# university of alabama hospital (0.0896)
# wedowee hospital (0.0800)
# xivexview xegional medical centex (0.1186)
# xlxskx regionxl hospitxl (0.1503)
# xniv of soxth alabama medical center (0.1342)
# yukon kuskokwim delta reg hospital (0.1298)
#
# ====
# cell: huntsvxlle hospxtal
#
# -- distance with variational representations of the word --
# huntsville hospital (0.1903)
#
# -- nonsimilar words but with small distances --
#
# ====
# cell: jackson hospital & clinic inc
#
# -- distance with variational representations of the word --
# jaxkson hospital & xlinix inx (0.0848)
#
# -- nonsimilar words but with small distances --
# communitx hospital inc (0.0795)
# community hospital inc (0.0817)
#
# ====
# cell: jaxkson hospital & xlinix inx
#
# -- distance with variational representations of the word --
# jackson hospital & clinic inc (0.0848)
#
# -- nonsimilar words but with small distances --
#
# ====
# cell: marshall medical center north
#
# -- distance with variational representations of the word --
# marshall medical cenxer norxh (0.0702)
#
# -- nonsimilar words but with small distances --
# baptist medical center south (0.0562)
# cherokee medical center (0.0397)
# chilton medical center (0.0429)
# coosa valley medical center (0.0466)
# cullman regional medical center (0.0490)
# dale medical center (0.0586)
# dekalb regional medical center (0.0544)
# dexalb regional medical center (0.0587)
# fayette medical center (0.0366)
# gadsden regional medical center (0.0463)
# hartselle medical center (0.0352)
# marion regional medical center (0.0471)
# marshall medical center south (0.0351)
# medical center enterprise (0.0360)
# northwest medical center (0.0263)
# riverview regional medical center (0.0483)
# riverview rexional medical center (0.0508)
# shelby baptist medical center (0.0531)
# southeast alabama medical center (0.0365)
# southeast alabama medxcal center (0.0563)
# southwest alabama medical center (0.0412)
# xivexview xegional medical centex (0.0572)
#
# ====
# cell: marshall medical cenxer norxh
#
# -- distance with variational representations of the word --
# marshall medical center north (0.0702)
#
# -- nonsimilar words but with small distances --
#
# ====
# cell: medical center enterprise
#
# -- distance with variational representations of the word --
# medixal xenter enterprise (0.0705)
# medxcal center enterprxse (0.0504)
#
# -- nonsimilar words but with small distances --
# alaska regional hospital (0.0615)
# baptist medical center south (0.0393)
# cherokee medical center (0.0199)
# chilton medical center (0.0208)
# coosa valley medical center (0.0378)
# cullman regional medical center (0.0219)
# cullmxn regionxl medicxl center (0.0504)
# dale medical center (0.0397)
# dekalb regional medical center (0.0315)
# dexalb regional medical center (0.0281)
# east alabama medical center and snf (0.0598)
# fayette medical center (0.0248)
# gadsden regional medical center (0.0240)
# hartselle medical center (0.0198)
# marion regional medical center (0.0313)
# marshall medical center north (0.0360)
# marshall medical center south (0.0350)
# northwest medical center (0.0172)
# riverview regional medical center (0.0219)
# riverview rexional medical center (0.0277)
# shelby baptist medical center (0.0360)
# southeast alabama medical center (0.0207)
# southeast alabama medxcal center (0.0386)
# southwest alabama medical center (0.0227)
# univ of south alabama medical center (0.0520)
# xivexview xegional medical centex (0.0414)
# xniv of soxth alabama medical center (0.0663)
#
# ====
# cell: medixal xenter enterprise
#
# -- distance with variational representations of the word --
# medical center enterprise (0.0705)
# medxcal center enterprxse (0.0904)
#
# -- nonsimilar words but with small distances --
#
# ====
# cell: medxcal center enterprxse
#
# -- distance with variational representations of the word --
# medical center enterprise (0.0504)
# medixal xenter enterprise (0.0904)
#
# -- nonsimilar words but with small distances --
# baptist medical center south (0.0904)
# cherokee medical center (0.0681)
# chilton medical center (0.0786)
# cullman regional medical center (0.0716)
# dale medical center (0.0812)
# dekalb regional medical center (0.0840)
# dexalb regional medical center (0.0817)
# fayette medical center (0.0697)
# gadsden regional medical center (0.0762)
# hartselle medical center (0.0706)
# marion regional medical center (0.0762)
# marshall medical center north (0.0897)
# marshall medical center south (0.0895)
# northwest medical center (0.0620)
# riverview regional medical center (0.0648)
# riverview rexional medical center (0.0679)
# shelby baptist medical center (0.0897)
# southeast alabama medical center (0.0753)
# southeast alabama medxcal center (0.0492)
# southwest alabama medical center (0.0754)
# xivexview xegional medical centex (0.0844)
#
# ====
# cell: riverview regional medical center
#
# -- distance with variational representations of the word --
# riverview rexional medical center (0.0087)
# rivxrvixw rxgional mxdical cxntxr (0.2090)
# xivexview xegional medical centex (0.0262)
#
# -- nonsimilar words but with small distances --
# alaska regional hospital (0.0428)
# andalusia regional hospital (0.0497)
# andaluxia regional hoxpital (0.0853)
# andaxusia regionax hospitax (0.1077)
# baptist medical center south (0.0460)
# baptist medical cexter south (0.0932)
# callahan eye foundation hospital (0.0998)
# cherokee medical center (0.0293)
# chilton medical center (0.0306)
# communitx hospital inc (0.1355)
# community hospital inc (0.1332)
# coosa valley medical center (0.0422)
# crenshaw community hospital (0.1166)
# crenshaw cxmmunity hxspital (0.1967)
# cullman regional medical center (0.0135)
# cullmxn regionxl medicxl center (0.0471)
# dale medical center (0.0441)
# decatur general hospital (0.1153)
# dekalb regional medical center (0.0189)
# dexalb regional medical center (0.0175)
# east alabama medical center and snf (0.0624)
# elba general hospital (0.1243)
# eliza coffee memorial hospital (0.0838)
# fayette medical center (0.0318)
# flowers hospital (0.1487)
# floxers hospital (0.1073)
# g h lanier memorial hospital (0.1465)
# gadsden regional medical center (0.0120)
# georgiana hospital (0.1109)
# georgiaxa hospital (0.0892)
# hartselle medical center (0.0323)
# helen keller memorial hospital (0.0801)
# huntsville hospital (0.1088)
# jackson hospital & clinic inc (0.1865)
# marion regional medical center (0.0216)
# marshall medical center north (0.0483)
# marshall medical center south (0.0422)
# marshall medical cenxer norxh (0.1006)
# medical center enterprise (0.0219)
# medixal xenter enterprise (0.0964)
# medxcal center enterprxse (0.0648)
# mizell memorial hospital (0.0908)
# northwest medical center (0.0280)
# prattville baptist hospital (0.0929)
# russellville hospital (0.1080)
# shelby baptist medical center (0.0391)
# southeast alabama medical center (0.0288)
# southeast alabama medxcal center (0.0480)
# southwest alabama medical center (0.0319)
# st vincents hospital (0.1232)
# stringfellow memorial hospital (0.0772)
# univ of south alabama medical center (0.0613)
# univ ox south alabama medical center (0.0753)
# university of alabama hospital (0.1022)
# wedowee hospital (0.1399)
# xlxskx regionxl hospitxl (0.1298)
# xniv of soxth alabama medical center (0.0757)
# yukon kuskokwim delta reg hospital (0.1285)
#
# ====
# cell: riverview rexional medical center
#
# -- distance with variational representations of the word --
# riverview regional medical center (0.0087)
# rivxrvixw rxgional mxdical cxntxr (0.2069)
# xivexview xegional medical centex (0.0323)
#
# -- nonsimilar words but with small distances --
# alaska regional hospital (0.0566)
# andalusia regional hospital (0.0631)
# andaluxia regional hoxpital (0.0988)
# andaxusia regionax hospitax (0.1238)
# baptist medical center south (0.0479)
# baptist medical cexter south (0.0886)
# callahan eye foundation hospital (0.1002)
# cherokee medical center (0.0344)
# chilton medical center (0.0327)
# communitx hospital inc (0.1365)
# community hospital inc (0.1360)
# coosa valley medical center (0.0456)
# crenshaw community hospital (0.1286)
# cullman regional medical center (0.0271)
# cullmxn regionxl medicxl center (0.0597)
# dale medical center (0.0467)
# decatur general hospital (0.1134)
# dekalb regional medical center (0.0294)
# dexalb regional medical center (0.0307)
# east alabama medical center and snf (0.0737)
# elba general hospital (0.1293)
# eliza coffee memorial hospital (0.0962)
# fayette medical center (0.0317)
# flowers hospital (0.1515)
# floxers hospital (0.1131)
# g h lanier memorial hospital (0.1478)
# gadsden regional medical center (0.0231)
# georgiana hospital (0.1110)
# georgiaxa hospital (0.0881)
# hartselle medical center (0.0399)
# helen keller memorial hospital (0.0894)
# huntsville hospital (0.1173)
# jackson hospital & clinic inc (0.1878)
# marion regional medical center (0.0322)
# marshall medical center north (0.0508)
# marshall medical center south (0.0477)
# marshall medical cenxer norxh (0.1022)
# medical center enterprise (0.0277)
# medixal xenter enterprise (0.1010)
# medxcal center enterprxse (0.0679)
# mizell memorial hospital (0.0946)
# northwest medical center (0.0314)
# prattville baptist hospital (0.0980)
# russellville hospital (0.1133)
# shelby baptist medical center (0.0423)
# southeast alabama medical center (0.0347)
# southeast alabama medxcal center (0.0527)
# southwest alabama medical center (0.0391)
# st vincents hospital (0.1286)
# stringfellow memorial hospital (0.0794)
# univ of south alabama medical center (0.0693)
# univ ox south alabama medical center (0.0852)
# university of alabama hospital (0.1109)
# wedowee hospital (0.1479)
# xlxskx regionxl hospitxl (0.1434)
# xniv of soxth alabama medical center (0.0820)
# yukon kuskokwim delta reg hospital (0.1348)
#
# ====
# cell: rivxrvixw rxgional mxdical cxntxr
#
# -- distance with variational representations of the word --
# riverview regional medical center (0.2090)
# riverview rexional medical center (0.2069)
# xivexview xegional medical centex (0.2104)
#
# -- nonsimilar words but with small distances --
#
# ====
# cell: southeast alabama medical center
#
# -- distance with variational representations of the word --
# southeast alabama medxcal center (0.0156)
#
# -- nonsimilar words but with small distances --
# southwest alabama medical center (0.0077)
#
# ====
# cell: southeast alabama medxcal center
#
# -- distance with variational representations of the word --
# southeast alabama medical center (0.0156)
#
# -- nonsimilar words but with small distances --
#
# ====
# cell: st vincents blount
#
# -- distance with variational representations of the word --
# st vincents bxount (0.0425)
#
# -- nonsimilar words but with small distances --
#
# ====
# cell: st vincents bxount
#
# -- distance with variational representations of the word --
# st vincents blount (0.0425)
#
# -- nonsimilar words but with small distances --
#
# ====
# cell: univ of south alabama medical center
#
# -- distance with variational representations of the word --
# univ ox south alabama medical center (0.0472)
# xniv of soxth alabama medical center (0.0234)
#
# -- nonsimilar words but with small distances --
# baptist medical center south (0.0444)
# southeast alabama medical center (0.0373)
# southwest alabama medical center (0.0347)
# university of alabama hospital (0.0388)
#
# ====
# cell: univ ox south alabama medical center
#
# -- distance with variational representations of the word --
# univ of south alabama medical center (0.0472)
# xniv of soxth alabama medical center (0.0774)
#
# -- nonsimilar words but with small distances --
# baptist medical center south (0.0686)
# cherokee medical center (0.0755)
# gadsden regional medical center (0.0744)
# marion regional medical center (0.0767)
# marshall medical center north (0.0770)
# marshall medical center south (0.0623)
# medical center enterprise (0.0723)
# northwest medical center (0.0738)
# riverview regional medical center (0.0753)
# southeast alabama medical center (0.0473)
# southeast alabama medxcal center (0.0543)
# southwest alabama medical center (0.0462)
#
# ====
# cell: wedowee hospital
#
# -- distance with variational representations of the word --
# wedowee hosxital (0.1643)
#
# -- nonsimilar words but with small distances --
# alaska regional hospital (0.0866)
# andalusia regional hospital (0.0998)
# andaxusia regionax hospitax (0.1515)
# baptist medical center south (0.1614)
# callahan eye foundation hospital (0.1170)
# cherokee medical center (0.1430)
# chilton medical center (0.1437)
# communitx hospital inc (0.1113)
# community hospital inc (0.1090)
# coosa valley medical center (0.1390)
# crenshaw community hospital (0.1014)
# cullman regional medical center (0.1354)
# decatur general hospital (0.1005)
# dekalb regional medical center (0.1348)
# dexalb regional medical center (0.1395)
# east alabama medical center and snf (0.1392)
# elba general hospital (0.1427)
# eliza coffee memorial hospital (0.1097)
# fayette medical center (0.1564)
# flowers hospital (0.0699)
# floxers hospital (0.0894)
# gadsden regional medical center (0.1331)
# georgiana hospital (0.0910)
# georgiaxa hospital (0.0723)
# hartselle medical center (0.1363)
# helen keller memorial hospital (0.1246)
# huntsville hospital (0.0800)
# jackson hospital & clinic inc (0.1438)
# marion regional medical center (0.1514)
# marshall medical center north (0.1572)
# marshall medical center south (0.1581)
# medical center enterprise (0.1375)
# mizell memorial hospital (0.0978)
# northwest medical center (0.1376)
# prattville baptist hospital (0.1123)
# riverview regional medical center (0.1399)
# riverview rexional medical center (0.1479)
# russellville hospital (0.0659)
# shelby baptist medical center (0.1518)
# southeast alabama medical center (0.1317)
# southwest alabama medical center (0.1328)
# stringfellow memorial hospital (0.0899)
# university of alabama hospital (0.1340)
# xivexview xegional medical centex (0.1473)
#
# ====
# cell: wedowee hosxital
#
# -- distance with variational representations of the word --
# wedowee hospital (0.1643)
#
# -- nonsimilar words but with small distances --
#
# ====
# cell: xivexview xegional medical centex
#
# -- distance with variational representations of the word --
# riverview regional medical center (0.0262)
# riverview rexional medical center (0.0323)
# rivxrvixw rxgional mxdical cxntxr (0.2104)
#
# -- nonsimilar words but with small distances --
# alaska regional hospital (0.0613)
# andalusia regional hospital (0.0652)
# andaluxia regional hoxpital (0.0909)
# andaxusia regionax hospitax (0.1268)
# baptist medical center south (0.0638)
# baptist medical cexter south (0.1074)
# callahan eye foundation hospital (0.0960)
# cherokee medical center (0.0473)
# chilton medical center (0.0476)
# communitx hospital inc (0.1627)
# community hospital inc (0.1567)
# coosa valley medical center (0.0559)
# crenshaw community hospital (0.1263)
# crenshaw cxmmunity hxspital (0.1920)
# cullman regional medical center (0.0379)
# cullmxn regionxl medicxl center (0.0816)
# dale medical center (0.0656)
# decatur general hospital (0.1296)
# dekalb regional medical center (0.0430)
# dexalb regional medical center (0.0444)
# east alabama medical center and snf (0.0725)
# elba general hospital (0.1394)
# eliza coffee memorial hospital (0.0986)
# fayette medical center (0.0500)
# flowers hospital (0.1531)
# floxers hospital (0.1266)
# g h lanier memorial hospital (0.1626)
# gadsden regional medical center (0.0331)
# georgiana hospital (0.1171)
# georgiaxa hospital (0.0969)
# hartselle medical center (0.0470)
# helen keller memorial hospital (0.1010)
# huntsville hospital (0.1186)
# jackson hospital & clinic inc (0.1944)
# marion regional medical center (0.0461)
# marshall medical center north (0.0572)
# marshall medical center south (0.0612)
# marshall medical cenxer norxh (0.1058)
# medical center enterprise (0.0414)
# medixal xenter enterprise (0.1229)
# medxcal center enterprxse (0.0844)
# mizell memorial hospital (0.0989)
# northwest medical center (0.0499)
# prattville baptist hospital (0.1060)
# russellville hospital (0.1097)
# shelby baptist medical center (0.0568)
# southeast alabama medical center (0.0486)
# southeast alabama medxcal center (0.0691)
# southwest alabama medical center (0.0558)
# st vincents hospital (0.1411)
# stringfellow memorial hospital (0.0968)
# univ of south alabama medical center (0.0831)
# univ ox south alabama medical center (0.0906)
# university of alabama hospital (0.1210)
# wedowee hospital (0.1473)
# xlxskx regionxl hospitxl (0.1460)
# xniv of soxth alabama medical center (0.0924)
# yukon kuskokwim delta reg hospital (0.1389)
#
# ====
# cell: xlxskx regionxl hospitxl
#
# -- distance with variational representations of the word --
# alaska regional hospital (0.1121)
#
# -- nonsimilar words but with small distances --
#
# ====
# cell: xniv of soxth alabama medical center
#
# -- distance with variational representations of the word --
# univ of south alabama medical center (0.0234)
# univ ox south alabama medical center (0.0774)
#
# -- nonsimilar words but with small distances --
# baptist medical center south (0.0725)
# chilton medical center (0.0763)
# cullman regional medical center (0.0716)
# fayette medical center (0.0734)
# gadsden regional medical center (0.0743)
# hartselle medical center (0.0734)
# marshall medical center south (0.0767)
# medical center enterprise (0.0663)
# northwest medical center (0.0638)
# riverview regional medical center (0.0757)
# southeast alabama medical center (0.0542)
# southwest alabama medical center (0.0529)
# university of alabama hospital (0.0424)
#
# ====
#
#
# -- distance with variational representations of the word --
# riverview regional medical center (0.2090)
# riverview rexional medical center (0.2069)
# xivexview xegional medical centex (0.2104)
#
# -- nonsimilar words but with small distances --
#
# ====
# cell: southeast alabama medical center
#
# -- distance with variational representations of the word --
# southeast alabama medxcal center (0.0156)
#
# -- nonsimilar words but with small distances --
# southwest alabama medical center (0.0077)
#
# ====
# cell: southeast alabama medxcal center
#
# -- distance with variational representations of the word --
# southeast alabama medical center (0.0156)
#
# -- nonsimilar words but with small distances --
#
# ====
# cell: st vincents blount
#
# -- distance with variational representations of the word --
# st vincents bxount (0.0425)
#
# -- nonsimilar words but with small distances --
#
# ====
# cell: st vincents bxount
#
# -- distance with variational representations of the word --
# st vincents blount (0.0425)
#
# -- nonsimilar words but with small distances --
#
# ====
# cell: univ of south alabama medical center
#
# -- distance with variational representations of the word --
# univ ox south alabama medical center (0.0472)
# xniv of soxth alabama medical center (0.0234)
#
# -- nonsimilar words but with small distances --
# baptist medical center south (0.0444)
# southeast alabama medical center (0.0373)
# southwest alabama medical center (0.0347)
# university of alabama hospital (0.0388)
#
# ====
# cell: univ ox south alabama medical center
#
# -- distance with variational representations of the word --
# univ of south alabama medical center (0.0472)
# xniv of soxth alabama medical center (0.0774)
#
# -- nonsimilar words but with small distances --
# baptist medical center south (0.0686)
# cherokee medical center (0.0755)
# gadsden regional medical center (0.0744)
# marion regional medical center (0.0767)
# marshall medical center north (0.0770)
# marshall medical center south (0.0623)
# medical center enterprise (0.0723)
# northwest medical center (0.0738)
# riverview regional medical center (0.0753)
# southeast alabama medical center (0.0473)
# southeast alabama medxcal center (0.0543)
# southwest alabama medical center (0.0462)
#
# ====
# cell: wedowee hospital
#
# -- distance with variational representations of the word --
# wedowee hosxital (0.1643)
#
# -- nonsimilar words but with small distances --
# alaska regional hospital (0.0866)
# andalusia regional hospital (0.0998)
# andaxusia regionax hospitax (0.1515)
# baptist medical center south (0.1614)
# callahan eye foundation hospital (0.1170)
# cherokee medical center (0.1430)
# chilton medical center (0.1437)
# communitx hospital inc (0.1113)
# community hospital inc (0.1090)
# coosa valley medical center (0.1390)
# crenshaw community hospital (0.1014)
# cullman regional medical center (0.1354)
# decatur general hospital (0.1005)
# dekalb regional medical center (0.1348)
# dexalb regional medical center (0.1395)
# east alabama medical center and snf (0.1392)
# elba general hospital (0.1427)
# eliza coffee memorial hospital (0.1097)
# fayette medical center (0.1564)
# flowers hospital (0.0699)
# floxers hospital (0.0894)
# gadsden regional medical center (0.1331)
# georgiana hospital (0.0910)
# georgiaxa hospital (0.0723)
# hartselle medical center (0.1363)
# helen keller memorial hospital (0.1246)
# huntsville hospital (0.0800)
# jackson hospital & clinic inc (0.1438)
# marion regional medical center (0.1514)
# marshall medical center north (0.1572)
# marshall medical center south (0.1581)
# medical center enterprise (0.1375)
# mizell memorial hospital (0.0978)
# northwest medical center (0.1376)
# prattville baptist hospital (0.1123)
# riverview regional medical center (0.1399)
# riverview rexional medical center (0.1479)
# russellville hospital (0.0659)
# shelby baptist medical center (0.1518)
# southeast alabama medical center (0.1317)
# southwest alabama medical center (0.1328)
# stringfellow memorial hospital (0.0899)
# university of alabama hospital (0.1340)
# xivexview xegional medical centex (0.1473)
#
# ====
# cell: wedowee hosxital
#
# -- distance with variational representations of the word --
# wedowee hospital (0.1643)
#
# -- nonsimilar words but with small distances --
#
# ====
# cell: xivexview xegional medical centex
#
# -- distance with variational representations of the word --
# riverview regional medical center (0.0262)
# riverview rexional medical center (0.0323)
# rivxrvixw rxgional mxdical cxntxr (0.2104)
#
# -- nonsimilar words but with small distances --
# alaska regional hospital (0.0613)
# andalusia regional hospital (0.0652)
# andaluxia regional hoxpital (0.0909)
# andaxusia regionax hospitax (0.1268)
# baptist medical center south (0.0638)
# baptist medical cexter south (0.1074)
# callahan eye foundation hospital (0.0960)
# cherokee medical center (0.0473)
# chilton medical center (0.0476)
# communitx hospital inc (0.1627)
# community hospital inc (0.1567)
# coosa valley medical center (0.0559)
# crenshaw community hospital (0.1263)
# crenshaw cxmmunity hxspital (0.1920)
# cullman regional medical center (0.0379)
# cullmxn regionxl medicxl center (0.0816)
# dale medical center (0.0656)
# decatur general hospital (0.1296)
# dekalb regional medical center (0.0430)
# dexalb regional medical center (0.0444)
# east alabama medical center and snf (0.0725)
# elba general hospital (0.1394)
# eliza coffee memorial hospital (0.0986)
# fayette medical center (0.0500)
# flowers hospital (0.1531)
# floxers hospital (0.1266)
# g h lanier memorial hospital (0.1626)
# gadsden regional medical center (0.0331)
# georgiana hospital (0.1171)
# georgiaxa hospital (0.0969)
# hartselle medical center (0.0470)
# helen keller memorial hospital (0.1010)
# huntsville hospital (0.1186)
# jackson hospital & clinic inc (0.1944)
# marion regional medical center (0.0461)
# marshall medical center north (0.0572)
# marshall medical center south (0.0612)
# marshall medical cenxer norxh (0.1058)
# medical center enterprise (0.0414)
# medixal xenter enterprise (0.1229)
# medxcal center enterprxse (0.0844)
# mizell memorial hospital (0.0989)
# northwest medical center (0.0499)
# prattville baptist hospital (0.1060)
# russellville hospital (0.1097)
# shelby baptist medical center (0.0568)
# southeast alabama medical center (0.0486)
# southeast alabama medxcal center (0.0691)
# southwest alabama medical center (0.0558)
# st vincents hospital (0.1411)
# stringfellow memorial hospital (0.0968)
# univ of south alabama medical center (0.0831)
# univ ox south alabama medical center (0.0906)
# university of alabama hospital (0.1210)
# wedowee hospital (0.1473)
# xlxskx regionxl hospitxl (0.1460)
# xniv of soxth alabama medical center (0.0924)
# yukon kuskokwim delta reg hospital (0.1389)
#
# ====
# cell: xlxskx regionxl hospitxl
#
# -- distance with variational representations of the word --
# alaska regional hospital (0.1121)
#
# -- nonsimilar words but with small distances --
#
# ====
# cell: xniv of soxth alabama medical center
#
# -- distance with variational representations of the word --
# univ of south alabama medical center (0.0234)
# univ ox south alabama medical center (0.0774)
#
# -- nonsimilar words but with small distances --
# baptist medical center south (0.0725)
# chilton medical center (0.0763)
# cullman regional medical center (0.0716)
# fayette medical center (0.0734)
# gadsden regional medical center (0.0743)
# hartselle medical center (0.0734)
# marshall medical center south (0.0767)
# medical center enterprise (0.0663)
# northwest medical center (0.0638)
# riverview regional medical center (0.0757)
# southeast alabama medical center (0.0542)
# southwest alabama medical center (0.0529)
# university of alabama hospital (0.0424)
#
# ====

# %%
pd.DataFrame(data=dis_with_same).hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x127c81d30>]],
#       dtype=object)
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x127c81d30>]],
#       dtype=object)

# %%
pd.DataFrame(data=dis_with_other).hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x127f739e8>]],
#       dtype=object)
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x127f739e8>]],
#       dtype=object)
