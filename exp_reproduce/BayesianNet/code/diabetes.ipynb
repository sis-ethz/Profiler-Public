# %%
from profiler.core import *

# %%
pf = Profiler(workers = 2, tol=1e-6, eps=0.05, embedtxt=True)

# %%
pf.session.load_data(name='diabetes', src=FILE, fpath='../table/diabetes/diabetes.csv', check_param=True, na_values='empty')
# Out:
# INFO:profiler.utility:[0.024634838104248047] Load Data start
#
# INFO:profiler.data.dataset:parameters used for data loading:
#  {'na_values': 'empty', 'sep': ',', 'header': 'infer', 'dropcol': None, 'dropna': False, 'encoding': 'utf-8', 'normalize': True, 'min_categories_for_embedding': 10}
# INFO:profiler.data.dataset:inferred types of attributes: {
#     "cho_bal_12": "text",
#     "bg_24": "text",
#     "bg_23": "text",
#     "bg_22": "text",
#     "bg_21": "text",
#     "ins_indep_util_21": "categorical",
#     "cho_bal_10": "text",
#     "cho_bal_11": "text",
#     "ins_abs_20": "text",
#     "ins_abs_21": "text",
#     "ins_abs_22": "text",
#     "ins_abs_23": "text",
#     "basal_bal_22": "text",
#     "basal_bal_23": "text",
#     "basal_bal_20": "text",
#     "basal_bal_21": "text",
#     "ins_dep_util_21": "categorical",
#     "ins_dep_util_20": "categorical",
#     "ins_dep_util_23": "categorical",
#     "ins_dep_util_22": "categorical",
#     "met_irr_6": "categorical",
#     "met_irr_7": "categorical",
#     "met_irr_4": "categorical",
#     "met_irr_5": "categorical",
#     "met_irr_2": "categorical",
#     "met_irr_3": "categorical",
#     "met_irr_0": "categorical",
#     "met_irr_1": "categorical",
#     "met_irr_8": "categorical",
#     "met_irr_9": "categorical",
#     "ins_indep_util_9": "categorical",
#     "ins_indep_util_8": "categorical",
#     "ins_abs_9": "text",
#     "ins_abs_8": "text",
#     "ins_abs_1": "text",
#     "ins_abs_0": "text",
#     "ins_abs_3": "text",
#     "ins_abs_2": "text",
#     "ins_abs_5": "text",
#     "ins_abs_4": "text",
#     "ins_abs_7": "text",
#     "ins_abs_6": "text",
#     "ins_indep_util_1": "categorical",
#     "tot_bal_9": "text",
#     "tot_bal_8": "text",
#     "ins_indep_util_0": "categorical",
#     "tot_bal_5": "text",
#     "tot_bal_4": "text",
#     "tot_bal_7": "text",
#     "tot_bal_6": "text",
#     "tot_bal_1": "text",
#     "tot_bal_0": "text",
#     "tot_bal_3": "text",
#     "tot_bal_2": "text",
#     "cho_4": "text",
#     "cho_5": "text",
#     "cho_6": "text",
#     "cho_7": "text",
#     "cho_0": "text",
#     "cho_1": "text",
#     "cho_2": "text",
#     "cho_3": "text",
#     "cho_8": "text",
#     "cho_9": "text",
#     "basal_bal_14": "text",
#     "bg_20": "text",
#     "activ_ins_6": "text",
#     "activ_ins_7": "text",
#     "activ_ins_4": "text",
#     "activ_ins_5": "text",
#     "activ_ins_2": "text",
#     "activ_ins_3": "text",
#     "activ_ins_0": "text",
#     "activ_ins_1": "text",
#     "ins_indep_22": "categorical",
#     "ins_indep_23": "categorical",
#     "ins_indep_20": "categorical",
#     "ins_indep_21": "categorical",
#     "activ_ins_8": "text",
#     "activ_ins_9": "text",
#     "ins_dep_util_14": "categorical",
#     "gut_abs_20": "categorical",
#     "gut_abs_21": "categorical",
#     "gut_abs_22": "categorical",
#     "gut_abs_23": "categorical",
#     "tot_bal_15": "text",
#     "tot_bal_14": "text",
#     "basal_bal_5": "text",
#     "basal_bal_4": "text",
#     "tot_bal_11": "text",
#     "tot_bal_10": "text",
#     "tot_bal_13": "text",
#     "tot_bal_12": "text",
#     "renal_cl_20": "categorical",
#     "renal_cl_21": "categorical",
#     "renal_cl_22": "categorical",
#     "renal_cl_23": "categorical",
#     "renal_cl_9": "categorical",
#     "renal_cl_8": "categorical",
#     "renal_cl_5": "categorical",
#     "renal_cl_4": "categorical",
#     "renal_cl_7": "categorical",
#     "renal_cl_6": "categorical",
#     "renal_cl_1": "categorical",
#     "renal_cl_0": "categorical",
#     "renal_cl_3": "categorical",
#     "renal_cl_2": "categorical",
#     "ins_dep_21": "text",
#     "ins_dep_20": "text",
#     "ins_dep_23": "text",
#     "ins_dep_22": "text",
#     "activ_ins_21": "text",
#     "activ_ins_20": "text",
#     "activ_ins_23": "text",
#     "activ_ins_22": "text",
#     "cho_24": "text",
#     "cho_23": "text",
#     "cho_22": "text",
#     "cho_21": "text",
#     "cho_20": "text",
#     "basal_bal_7": "text",
#     "basal_bal_6": "text",
#     "tot_bal_17": "text",
#     "tot_bal_16": "text",
#     "basal_bal_3": "text",
#     "basal_bal_2": "text",
#     "basal_bal_1": "text",
#     "basal_bal_0": "text",
#     "tot_bal_19": "text",
#     "tot_bal_18": "text",
#     "basal_bal_9": "text",
#     "basal_bal_8": "text",
#     "ins_dep_6": "text",
#     "ins_dep_7": "text",
#     "ins_dep_4": "text",
#     "ins_dep_5": "text",
#     "ins_dep_2": "text",
#     "ins_dep_3": "text",
#     "ins_dep_0": "text",
#     "ins_dep_1": "text",
#     "ins_dep_8": "text",
#     "ins_dep_9": "text",
#     "bg_0": "text",
#     "bg_1": "text",
#     "bg_2": "text",
#     "bg_3": "text",
#     "bg_4": "text",
#     "bg_5": "text",
#     "bg_6": "text",
#     "bg_7": "text",
#     "bg_8": "text",
#     "bg_9": "text",
#     "endo_bal_20": "text",
#     "endo_bal_21": "text",
#     "endo_bal_22": "text",
#     "endo_bal_23": "text",
#     "gut_abs_1": "categorical",
#     "cho_bal_1": "text",
#     "gut_abs_3": "categorical",
#     "gut_abs_2": "categorical",
#     "cho_bal_4": "text",
#     "cho_bal_5": "text",
#     "cho_bal_6": "text",
#     "cho_bal_7": "text",
#     "gut_abs_9": "categorical",
#     "cho_bal_9": "text",
#     "activ_ins_18": "text",
#     "activ_ins_19": "text",
#     "activ_ins_10": "text",
#     "activ_ins_11": "text",
#     "activ_ins_12": "text",
#     "activ_ins_13": "text",
#     "activ_ins_14": "text",
#     "activ_ins_15": "text",
#     "activ_ins_16": "text",
#     "activ_ins_17": "text",
#     "cho_16": "text",
#     "cho_17": "text",
#     "cho_14": "text",
#     "cho_15": "text",
#     "cho_12": "text",
#     "cho_13": "text",
#     "cho_10": "text",
#     "cho_11": "text",
#     "cho_bal_23": "text",
#     "cho_bal_22": "text",
#     "cho_bal_21": "text",
#     "cho_bal_20": "text",
#     "cho_18": "text",
#     "cho_19": "text",
#     "meal_10": "text",
#     "meal_11": "text",
#     "meal_12": "text",
#     "meal_13": "text",
#     "meal_14": "text",
#     "meal_15": "text",
#     "meal_16": "text",
#     "meal_17": "text",
#     "meal_18": "text",
#     "meal_19": "text",
#     "ins_indep_util_3": "categorical",
#     "ins_indep_util_2": "categorical",
#     "ins_indep_util_5": "categorical",
#     "ins_indep_util_4": "categorical",
#     "ins_indep_util_7": "categorical",
#     "ins_indep_util_6": "categorical",
#     "renal_cl_19": "categorical",
#     "renal_cl_18": "categorical",
#     "renal_cl_11": "categorical",
#     "renal_cl_10": "categorical",
#     "renal_cl_13": "categorical",
#     "renal_cl_12": "categorical",
#     "renal_cl_15": "categorical",
#     "renal_cl_14": "categorical",
#     "renal_cl_17": "categorical",
#     "renal_cl_16": "categorical",
#     "glu_prod_1": "categorical",
#     "glu_prod_0": "categorical",
#     "glu_prod_3": "categorical",
#     "glu_prod_2": "categorical",
#     "glu_prod_5": "categorical",
#     "glu_prod_4": "categorical",
#     "glu_prod_7": "categorical",
#     "glu_prod_6": "categorical",
#     "glu_prod_9": "categorical",
#     "glu_prod_8": "categorical",
#     "cho_init": "text",
#     "met_irr_21": "categorical",
#     "met_irr_20": "categorical",
#     "met_irr_23": "categorical",
#     "met_irr_22": "categorical",
#     "bg_17": "text",
#     "ins_dep_10": "text",
#     "ins_dep_11": "text",
#     "ins_dep_12": "text",
#     "meal_9": "text",
#     "ins_dep_14": "text",
#     "ins_dep_15": "text",
#     "ins_dep_16": "text",
#     "ins_dep_17": "text",
#     "meal_2": "text",
#     "ins_dep_19": "text",
#     "meal_0": "text",
#     "meal_1": "text",
#     "meal_6": "text",
#     "meal_7": "text",
#     "meal_4": "text",
#     "meal_5": "text",
#     "meal_8": "text",
#     "ins_dep_13": "text",
#     "ins_indep_util_20": "categorical",
#     "cho_bal_13": "text",
#     "ins_indep_util_22": "categorical",
#     "ins_indep_util_23": "categorical",
#     "cho_bal_16": "text",
#     "cho_bal_17": "text",
#     "cho_bal_14": "text",
#     "cho_bal_15": "text",
#     "cho_bal_18": "text",
#     "cho_bal_19": "text",
#     "ins_dep_18": "text",
#     "meal_3": "text",
#     "glu_prod_20": "categorical",
#     "glu_prod_21": "categorical",
#     "glu_prod_22": "categorical",
#     "glu_prod_23": "categorical",
#     "ins_dep_util_2": "categorical",
#     "ins_dep_util_3": "categorical",
#     "ins_dep_util_0": "categorical",
#     "ins_dep_util_1": "categorical",
#     "ins_dep_util_6": "categorical",
#     "ins_dep_util_7": "categorical",
#     "ins_dep_util_4": "categorical",
#     "ins_dep_util_5": "categorical",
#     "ins_dep_util_8": "categorical",
#     "ins_dep_util_9": "categorical",
#     "tot_bal_20": "text",
#     "tot_bal_21": "text",
#     "tot_bal_22": "text",
#     "tot_bal_23": "text",
#     "endo_bal_9": "text",
#     "endo_bal_8": "text",
#     "endo_bal_1": "text",
#     "endo_bal_0": "text",
#     "endo_bal_3": "text",
#     "endo_bal_2": "text",
#     "endo_bal_5": "text",
#     "endo_bal_4": "text",
#     "endo_bal_7": "text",
#     "endo_bal_6": "text",
#     "endo_bal_19": "text",
#     "endo_bal_18": "text",
#     "endo_bal_15": "text",
#     "endo_bal_14": "text",
#     "endo_bal_17": "text",
#     "endo_bal_16": "text",
#     "endo_bal_11": "text",
#     "endo_bal_10": "text",
#     "endo_bal_13": "text",
#     "endo_bal_12": "text",
#     "ins_indep_util_11": "categorical",
#     "bg_18": "text",
#     "bg_19": "text",
#     "ins_indep_util_10": "categorical",
#     "bg_12": "text",
#     "bg_13": "text",
#     "bg_10": "text",
#     "bg_11": "text",
#     "bg_16": "text",
#     "basal_bal_11": "text",
#     "bg_14": "text",
#     "bg_15": "text",
#     "ins_indep_util_12": "categorical",
#     "basal_bal_17": "text",
#     "basal_bal_16": "text",
#     "ins_abs_19": "text",
#     "ins_abs_18": "text",
#     "basal_bal_15": "text",
#     "ins_abs_11": "text",
#     "ins_abs_10": "text",
#     "ins_abs_13": "text",
#     "ins_abs_12": "text",
#     "ins_abs_15": "text",
#     "ins_abs_14": "text",
#     "ins_abs_17": "text",
#     "ins_abs_16": "text",
#     "ins_indep_util_19": "categorical",
#     "ins_indep_util_18": "categorical",
#     "basal_bal_19": "text",
#     "basal_bal_18": "text",
#     "basal_bal_13": "text",
#     "basal_bal_12": "text",
#     "ins_indep_util_13": "categorical",
#     "basal_bal_10": "text",
#     "ins_indep_util_15": "categorical",
#     "ins_indep_util_14": "categorical",
#     "ins_indep_util_17": "categorical",
#     "ins_indep_util_16": "categorical",
#     "ins_sens": "categorical",
#     "ins_dep_util_18": "categorical",
#     "ins_dep_util_19": "categorical",
#     "ins_dep_util_10": "categorical",
#     "meal_24": "text",
#     "ins_dep_util_12": "categorical",
#     "ins_dep_util_13": "categorical",
#     "meal_21": "text",
#     "ins_dep_util_15": "categorical",
#     "ins_dep_util_16": "categorical",
#     "ins_dep_util_17": "categorical",
#     "cho_bal_0": "text",
#     "gut_abs_0": "categorical",
#     "cho_bal_2": "text",
#     "cho_bal_3": "text",
#     "gut_abs_5": "categorical",
#     "gut_abs_4": "categorical",
#     "gut_abs_7": "categorical",
#     "gut_abs_6": "categorical",
#     "cho_bal_8": "text",
#     "gut_abs_8": "categorical",
#     "ins_dep_util_11": "categorical",
#     "met_irr_10": "categorical",
#     "met_irr_11": "categorical",
#     "met_irr_12": "categorical",
#     "met_irr_13": "categorical",
#     "met_irr_14": "categorical",
#     "met_irr_15": "categorical",
#     "met_irr_16": "categorical",
#     "met_irr_17": "categorical",
#     "met_irr_18": "categorical",
#     "met_irr_19": "categorical",
#     "meal_20": "text",
#     "meal_23": "text",
#     "meal_22": "text",
#     "ins_indep_9": "categorical",
#     "ins_indep_8": "categorical",
#     "ins_indep_3": "categorical",
#     "ins_indep_2": "categorical",
#     "ins_indep_1": "categorical",
#     "ins_indep_0": "categorical",
#     "ins_indep_7": "categorical",
#     "ins_indep_6": "categorical",
#     "ins_indep_5": "categorical",
#     "ins_indep_4": "categorical",
#     "ins_indep_19": "categorical",
#     "ins_indep_18": "categorical",
#     "ins_indep_17": "categorical",
#     "ins_indep_16": "categorical",
#     "ins_indep_15": "categorical",
#     "ins_indep_14": "categorical",
#     "ins_indep_13": "categorical",
#     "ins_indep_12": "categorical",
#     "ins_indep_11": "categorical",
#     "ins_indep_10": "categorical",
#     "gut_abs_11": "categorical",
#     "gut_abs_10": "categorical",
#     "gut_abs_13": "categorical",
#     "gut_abs_12": "categorical",
#     "gut_abs_15": "categorical",
#     "gut_abs_14": "categorical",
#     "gut_abs_17": "categorical",
#     "gut_abs_16": "categorical",
#     "gut_abs_19": "categorical",
#     "gut_abs_18": "categorical",
#     "glu_prod_15": "categorical",
#     "glu_prod_14": "categorical",
#     "glu_prod_17": "categorical",
#     "glu_prod_16": "categorical",
#     "glu_prod_11": "categorical",
#     "glu_prod_10": "categorical",
#     "glu_prod_13": "categorical",
#     "glu_prod_12": "categorical",
#     "glu_prod_19": "categorical",
#     "glu_prod_18": "categorical"
# }
# INFO:profiler.data.dataset:(possible types: numeric, categorical, text, date)
# INFO:profiler.data.dataset:inferred operators of attributes: {'cho_bal_12': ['equal'], 'bg_24': ['equal'], 'bg_23': ['equal'], 'bg_22': ['equal'], 'bg_21': ['equal'], 'ins_indep_util_21': ['equal'], 'cho_bal_10': ['equal'], 'cho_bal_11': ['equal'], 'ins_abs_20': ['equal'], 'ins_abs_21': ['equal'], 'ins_abs_22': ['equal'], 'ins_abs_23': ['equal'], 'basal_bal_22': ['equal'], 'basal_bal_23': ['equal'], 'basal_bal_20': ['equal'], 'basal_bal_21': ['equal'], 'ins_dep_util_21': ['equal'], 'ins_dep_util_20': ['equal'], 'ins_dep_util_23': ['equal'], 'ins_dep_util_22': ['equal'], 'met_irr_6': ['equal'], 'met_irr_7': ['equal'], 'met_irr_4': ['equal'], 'met_irr_5': ['equal'], 'met_irr_2': ['equal'], 'met_irr_3': ['equal'], 'met_irr_0': ['equal'], 'met_irr_1': ['equal'], 'met_irr_8': ['equal'], 'met_irr_9': ['equal'], 'ins_indep_util_9': ['equal'], 'ins_indep_util_8': ['equal'], 'ins_abs_9': ['equal'], 'ins_abs_8': ['equal'], 'ins_abs_1': ['equal'], 'ins_abs_0': ['equal'], 'ins_abs_3': ['equal'], 'ins_abs_2': ['equal'], 'ins_abs_5': ['equal'], 'ins_abs_4': ['equal'], 'ins_abs_7': ['equal'], 'ins_abs_6': ['equal'], 'ins_indep_util_1': ['equal'], 'tot_bal_9': ['equal'], 'tot_bal_8': ['equal'], 'ins_indep_util_0': ['equal'], 'tot_bal_5': ['equal'], 'tot_bal_4': ['equal'], 'tot_bal_7': ['equal'], 'tot_bal_6': ['equal'], 'tot_bal_1': ['equal'], 'tot_bal_0': ['equal'], 'tot_bal_3': ['equal'], 'tot_bal_2': ['equal'], 'cho_4': ['equal'], 'cho_5': ['equal'], 'cho_6': ['equal'], 'cho_7': ['equal'], 'cho_0': ['equal'], 'cho_1': ['equal'], 'cho_2': ['equal'], 'cho_3': ['equal'], 'cho_8': ['equal'], 'cho_9': ['equal'], 'basal_bal_14': ['equal'], 'bg_20': ['equal'], 'activ_ins_6': ['equal'], 'activ_ins_7': ['equal'], 'activ_ins_4': ['equal'], 'activ_ins_5': ['equal'], 'activ_ins_2': ['equal'], 'activ_ins_3': ['equal'], 'activ_ins_0': ['equal'], 'activ_ins_1': ['equal'], 'ins_indep_22': ['equal'], 'ins_indep_23': ['equal'], 'ins_indep_20': ['equal'], 'ins_indep_21': ['equal'], 'activ_ins_8': ['equal'], 'activ_ins_9': ['equal'], 'ins_dep_util_14': ['equal'], 'gut_abs_20': ['equal'], 'gut_abs_21': ['equal'], 'gut_abs_22': ['equal'], 'gut_abs_23': ['equal'], 'tot_bal_15': ['equal'], 'tot_bal_14': ['equal'], 'basal_bal_5': ['equal'], 'basal_bal_4': ['equal'], 'tot_bal_11': ['equal'], 'tot_bal_10': ['equal'], 'tot_bal_13': ['equal'], 'tot_bal_12': ['equal'], 'renal_cl_20': ['equal'], 'renal_cl_21': ['equal'], 'renal_cl_22': ['equal'], 'renal_cl_23': ['equal'], 'renal_cl_9': ['equal'], 'renal_cl_8': ['equal'], 'renal_cl_5': ['equal'], 'renal_cl_4': ['equal'], 'renal_cl_7': ['equal'], 'renal_cl_6': ['equal'], 'renal_cl_1': ['equal'], 'renal_cl_0': ['equal'], 'renal_cl_3': ['equal'], 'renal_cl_2': ['equal'], 'ins_dep_21': ['equal'], 'ins_dep_20': ['equal'], 'ins_dep_23': ['equal'], 'ins_dep_22': ['equal'], 'activ_ins_21': ['equal'], 'activ_ins_20': ['equal'], 'activ_ins_23': ['equal'], 'activ_ins_22': ['equal'], 'cho_24': ['equal'], 'cho_23': ['equal'], 'cho_22': ['equal'], 'cho_21': ['equal'], 'cho_20': ['equal'], 'basal_bal_7': ['equal'], 'basal_bal_6': ['equal'], 'tot_bal_17': ['equal'], 'tot_bal_16': ['equal'], 'basal_bal_3': ['equal'], 'basal_bal_2': ['equal'], 'basal_bal_1': ['equal'], 'basal_bal_0': ['equal'], 'tot_bal_19': ['equal'], 'tot_bal_18': ['equal'], 'basal_bal_9': ['equal'], 'basal_bal_8': ['equal'], 'ins_dep_6': ['equal'], 'ins_dep_7': ['equal'], 'ins_dep_4': ['equal'], 'ins_dep_5': ['equal'], 'ins_dep_2': ['equal'], 'ins_dep_3': ['equal'], 'ins_dep_0': ['equal'], 'ins_dep_1': ['equal'], 'ins_dep_8': ['equal'], 'ins_dep_9': ['equal'], 'bg_0': ['equal'], 'bg_1': ['equal'], 'bg_2': ['equal'], 'bg_3': ['equal'], 'bg_4': ['equal'], 'bg_5': ['equal'], 'bg_6': ['equal'], 'bg_7': ['equal'], 'bg_8': ['equal'], 'bg_9': ['equal'], 'endo_bal_20': ['equal'], 'endo_bal_21': ['equal'], 'endo_bal_22': ['equal'], 'endo_bal_23': ['equal'], 'gut_abs_1': ['equal'], 'cho_bal_1': ['equal'], 'gut_abs_3': ['equal'], 'gut_abs_2': ['equal'], 'cho_bal_4': ['equal'], 'ch ...
# INFO:profiler.data.dataset:(possible operators: equal, notequal, greater_than, less_than)
# INFO:profiler.utility:[2.0538830757141113] Load Data execution time: 2.0292482376098633

# %%
pf.session.load_training_data(multiplier = None)
# Out:
# INFO:profiler.utility:[2.0612635612487793] Create Training Data start
#
# INFO:profiler.data.transformer:needs multiplier = 498 to bound the error in inv cov estimation <= 0.05000000
# INFO:profiler.data.transformer:use multiplier = 498, and the bound is 0.00058642
# INFO:profiler.data.transformer:Draw Pairs
#  72%|███████▏  | 296/413 [00:21<00:08, 13.43it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-5eba906ed09a> in <module>()
# ----> 1 pf.session.load_training_data(multiplier = None)
#
# /mnt/c/Users/Yunjia/Onedrive - UW-Madison/Database/Profiler/Profiler-Public/profiler/core.py in load_training_data(self, multiplier, sample_frac, difference)
#     224         self.timer.time_start('Create Training Data')
#     225         self.trans_engine.create_training_data(multiplier=multiplier, sample_frac=sample_frac,
# --> 226                                                embed=self.embed, difference=difference)
#     227         self.timer.time_end('Create Training Data')
#     228
#
# /mnt/c/Users/Yunjia/Onedrive - UW-Madison/Database/Profiler/Profiler-Public/profiler/data/transformer.py in create_training_data(self, multiplier, sample_frac, embed, difference)
#     201
#     202         logger.info("Draw Pairs")
# --> 203         left, right, self.left_idx, self.right_idx = self.create_pair_data(multiplier, sample_frac)
#     204
#     205         logger.info("Computing Differences")
#
# /mnt/c/Users/Yunjia/Onedrive - UW-Madison/Database/Profiler/Profiler-Public/profiler/data/transformer.py in create_pair_data(self, multiplier, sample_frac, attr_sort)
#     266             left = [base_table] * multiplier
#     267             right = [base_table.iloc[list(range(i+1, base_table.shape[0])) + list(range(i+1)), :].reset_index(
# --> 268                 drop=True) for i in range(multiplier)]
#     269             lefts.extend(left)
#     270             rights.extend(right)
#
# /mnt/c/Users/Yunjia/Onedrive - UW-Madison/Database/Profiler/Profiler-Public/profiler/data/transformer.py in <listcomp>(.0)
#     266             left = [base_table] * multiplier
#     267             right = [base_table.iloc[list(range(i+1, base_table.shape[0])) + list(range(i+1)), :].reset_index(
# --> 268                 drop=True) for i in range(multiplier)]
#     269             lefts.extend(left)
#     270             rights.extend(right)
#
# /root/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in reset_index(self, level, drop, inplace, col_level, col_fill)
#    2972             new_obj = self
#    2973         else:
# -> 2974             new_obj = self.copy()
#    2975
#    2976         def _maybe_casted_values(index, labels=None):
#
# /root/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in copy(self, deep)
#    3074         copy : type of caller
#    3075         """
# -> 3076         data = self._data.copy(deep=deep)
#    3077         return self._constructor(data).__finalize__(self)
#    3078
#
# /root/anaconda3/lib/python3.6/site-packages/pandas/core/internals.py in copy(self, deep, mgr)
#    3387             new_axes = list(self.axes)
#    3388         return self.apply('copy', axes=new_axes, deep=deep,
# -> 3389                           do_integrity_check=False)
#    3390
#    3391     def as_matrix(self, items=None):
#
# /root/anaconda3/lib/python3.6/site-packages/pandas/core/internals.py in apply(self, f, axes, filter, do_integrity_check, consolidate, **kwargs)
#    3054
#    3055             kwargs['mgr'] = self
# -> 3056             applied = getattr(b, f)(**kwargs)
#    3057             result_blocks = _extend_blocks(applied, result_blocks)
#    3058
#
# /root/anaconda3/lib/python3.6/site-packages/pandas/core/internals.py in copy(self, deep, mgr)
#     610         values = self.values
#     611         if deep:
# --> 612             values = values.copy()
#     613         return self.make_block_same_class(values)
#     614
#
# KeyboardInterrupt:

# %%
autoregress_matrix = pf.session.learn_structure(sparsity=0, infer_order=True)

# %%
parent_sets = pf.session.get_dependencies(score="fit_error")

# %%
pf.session.visualize_covariance()

# %%
pf.session.visualize_inverse_covariance()

# %%
pf.session.visualize_autoregression()

# %%
pf.session.timer.get_stat()
pf.session.timer.to_csv()
