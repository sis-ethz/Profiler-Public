# %%
from profiler.core import *
pf = Profiler(workers = 2, tol=1e-6, eps=0.05, embedtxt=True)

# %%
pf.session.load_data(name='eeg', src=FILE, fpath='./hce_data/eeg2/eeg2.csv', check_param=True, na_values='empty')
# Out:
# INFO:profiler.utility:[0.005196094512939453] Load Data start
#
# INFO:profiler.data.dataset:parameters used for data loading:
#  {'na_values': 'empty', 'sep': ',', 'header': 'infer', 'dropcol': None, 'dropna': False, 'encoding': 'utf-8', 'normalize': True, 'min_categories_for_embedding': 10}
# INFO:profiler.data.dataset:inferred types of attributes: {
#     "AF3": "numeric",
#     "F7": "numeric",
#     "F3": "numeric",
#     "FC5": "numeric",
#     "T7": "numeric",
#     "P7": "numeric",
#     "O1": "numeric",
#     "O2": "numeric",
#     "P8": "numeric",
#     "T8": "numeric",
#     "FC6": "numeric",
#     "F4": "numeric",
#     "F8": "numeric",
#     "AF4": "numeric",
#     "eyeDetection": "numeric"
# }
# INFO:profiler.data.dataset:(possible types: numeric, categorical, text, date)
# INFO:profiler.data.dataset:inferred operators of attributes: {'AF3': ['equal'], 'F7': ['equal'], 'F3': ['equal'], 'FC5': ['equal'], 'T7': ['equal'], 'P7': ['equal'], 'O1': ['equal'], 'O2': ['equal'], 'P8': ['equal'], 'T8': ['equal'], 'FC6': ['equal'], 'F4': ['equal'], 'F8': ['equal'], 'AF4': ['equal'], 'eyeDetection': ['equal']}
# INFO:profiler.data.dataset:(possible operators: equal, notequal, greater_than, less_than)
# INFO:profiler.utility:[0.10949873924255371] Load Data execution time: 0.10430264472961426

# %%
pf.session.load_training_data(multiplier = None)
# Out:
# INFO:profiler.utility:[0.12186694145202637] Create Training Data start
#
# INFO:profiler.data.transformer:needs multiplier = 1 to bound the error in inv cov estimation <= 0.05000000
# INFO:profiler.data.transformer:use multiplier = 1, and the bound is 0.00070981
# INFO:profiler.data.transformer:Draw Pairs
# 100%|██████████| 15/15 [00:00<00:00, 53.91it/s]
# INFO:profiler.data.transformer:Number of training samples: 224640
# INFO:profiler.data.transformer:Computing Differences
# INFO:profiler.data.transformer:estimated missing data probability in training data is 0.0000
# INFO:profiler.utility:[1.3934032917022705] Create Training Data execution time: 1.2715363502502441

# %%
# set sparsity to 0 for exp_reproduce 
autoregress_matrix = pf.session.learn_structure(sparsity=0, infer_order=True)
# Out:
# INFO:profiler.utility:[1.399449110031128] Learn Structure start
#
# INFO:profiler.learner:use threshold 0.2016
# INFO:profiler.utility:[1.679832935333252] Learn Structure execution time: 0.280383825302124

# %%
parent_sets = pf.session.get_dependencies(score="fit_error")
# Out:
# INFO:profiler.utility:[1.6902143955230713] Get Dependencies start
#
# INFO:profiler.utility:[1.697138786315918] Get Dependencies execution time: 0.00692439079284668

# %%
pf.session.visualize_covariance()
# Out:
# /root/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
pf.session.visualize_inverse_covariance()
# Out:
# /root/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
pf.session.visualize_autoregression()
# Out:
# /root/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
